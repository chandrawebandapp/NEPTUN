# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import pandas as pd
from tqdm.notebook import tqdm

# %%
df = pd.read_excel('/content/drive/MyDrive/daraz/Share_Review.xlsx', names=['Product', 'Review', 'Rating'])
df.head()
# Out:
#                                              Product  \
# 0  Moisture Matte Long Stay Lipstick - 2g | Espre...
# 1  ComfySlim 3 in 1 Postpartum Support Recovery B...
# 2                    Cosmetic Organizer/ Storage Box
# 3  Khadi Natural Hand Cream Milk & Saffron - With...
# 4               Newari Shahi Pulao Basmati Rice 5 Kg
#
#                                               Review  Rating
# 0  It’s good tara halka fohor deliver garidinu va...       3
# 1  good according to its price.. material chai al...       5
# 2                                                  -       4
# 3  I ordered this product for my mom and she love...       5
# 4                                                  -       5

# %%
df.Rating.value_counts()
# Out:
# Rating
# 5    24617
# 4     3640
# 1     2960
# 3     2169
# 2     1055
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Product    2
# Review     1
# Rating     0
# dtype: int64

# %%
df = df[~df["Review"].isin(["", "-"])]

# %%
df.Rating.value_counts()
# Out:
# Rating
# 5    10967
# 1     2279
# 4     1436
# 3     1063
# 2      694
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Product    0
# Review     1
# Rating     0
# dtype: int64

# %%
df.dropna()
# Out:
#                                                  Product  \
# 0      Moisture Matte Long Stay Lipstick - 2g | Espre...
# 1      ComfySlim 3 in 1 Postpartum Support Recovery B...
# 3      Khadi Natural Hand Cream Milk & Saffron - With...
# 6      Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8      Hoco UPA20 3.5 audio extension cable male to f...
# ...                                                  ...
# 34427  Pebbles Nepal 10 pieces Long Lasting Natural P...
# 34429  Silver Crest Electric Meat Grinder 3 ltr ( 1 Y...
# 34435  Black Waterproof And Windproof Touch Screen Glove
# 34436                              Polar Gown For Ladies
# 34438    KITO Slippers for Men- Kito AH83M- Black Slides
#
#                                                   Review  Rating
# 0      It’s good tara halka fohor deliver garidinu va...       3
# 1      good according to its price.. material chai al...       5
# 3      I ordered this product for my mom and she love...       5
# 6                                        Nice and useful       5
# 8      First of all quick shipping and delivery(recei...       5
# ...                                                  ...     ...
# 34427  ahhh...... tattoo was good hai but lagaune man...       5
# 34429                               Got damaged product.       1
# 34435  windproof and waterproof, warm fur inside. Mat...       5
# 34436  maile magako color  purple aayo pink j gare ni...       1
# 34438  came In a well-packaged condition. Was good as...       5
#
# [16438 rows x 3 columns]

# %%
import string
import re
import nltk
import nltk.corpus
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# Stopwords
Stopwords = set(nltk.corpus.stopwords.words("english")) - set(["not"])

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.2-py3-none-any.whl.metadata (9.4 kB)
# Downloading pyspellchecker-0.8.2-py3-none-any.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 42.6 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.2

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import words, wordnet as wn
from spellchecker import SpellChecker

# Download necessary resources
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("words")

# Initialize lemmatizer and spell checker
Lemmatizer = WordNetLemmatizer()
spell = SpellChecker()

# Load English words dictionary
english_vocab = set(words.words())

# Define stopwords (excluding "not")
Stopwords = set(nltk.corpus.stopwords.words("english")) - {"not"}

def is_strictly_english(word):
    """Check if a word is a valid English word using NLTK dictionary and WordNet."""
    return word.lower() in english_vocab or bool(wn.synsets(word))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
import unicodedata

def normalize_unicode_text(text):
    return unicodedata.normalize('NFKD', text)  # Normalizes text to decomposed form

# # Example
# word = "𝐠𝐨𝐨𝐝 𝐠𝐨𝐨𝐝"
# normalized_word = normalize_unicode_text(word)
# print(normalized_word)
# normalized_word.lower() in english_vocab or bool(wn.synsets(normalized_word))

# %%
import re

# Function to remove all emojis using Unicode ranges
def remove_emojis(text):
    # Define a regex pattern to match emojis
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols and pictographs
        "\U0001F680-\U0001F6FF"  # Transport and map symbols
        "\U0001F700-\U0001F77F"  # Alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric shapes
        "\U0001F800-\U0001F8FF"  # Supplemental arrows
        "\U0001F900-\U0001F9FF"  # Supplemental symbols and pictographs
        "\U0001FA00-\U0001FA6F"  # Chess symbols
        "\U0001FA70-\U0001FAFF"  # Symbols for legacy computing
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"  # Enclosed characters
        "]", flags=re.UNICODE
    )

    # Replace emojis with a space
    return emoji_pattern.sub(" ", text)

# Example string with emojis
text = "🙏🏻♥️masala bujado majjako 🙏🏻🙏🏻 sakthyo yeshlai tamika duitai😑😑"

# Remove all emojis
updated_text = remove_emojis(text)

print(updated_text)
# Out:
#     masala bujado majjako      sakthyo yeshlai tamika duitai

# %%
import re

# Function to check if text contains Devanagari script
def contains_devanagari(text):
    if isinstance(text, str):  # Ensure the input is a string
        return bool(re.search(r'[\u0900-\u097F]', text))
    return False

# %%
PREDEFINED_WORD=["positiveemoji", "negativeemoji", "facebook", "motherboard", "bhatbateni", "bluetooth"]

# %%
df = df[~df["Review"].apply(contains_devanagari)]

# %%
df.head()
# Out:
#                                              Product  \
# 0  Moisture Matte Long Stay Lipstick - 2g | Espre...
# 1  ComfySlim 3 in 1 Postpartum Support Recovery B...
# 3  Khadi Natural Hand Cream Milk & Saffron - With...
# 6  Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8  Hoco UPA20 3.5 audio extension cable male to f...
#
#                                               Review  Rating
# 0  It’s good tara halka fohor deliver garidinu va...       3
# 1  good according to its price.. material chai al...       5
# 3  I ordered this product for my mom and she love...       5
# 6                                    Nice and useful       5
# 8  First of all quick shipping and delivery(recei...       5

# %%
import re

# Define a dictionary of common merged words and their correct form
MERGED_WORDS = {
    "thankyou": "thank you",
    "nthankyou":  "thank you",
    "nthankyouu":  "thank you",
    "thankyouuu":  "thank you",
    "nthankyouu":  "thank you",
    "goodmorning": "good morning",
    "goodnight": "good night",
    "checkout": "check out",
    "wanna": "want to",
    "gonna": "going to",
    "cant": "can't",
    "dont": "don't",
    "doesnt": "doesn't",
    "isnt": "isn't",
    "havent": "haven't",
    "ive": "I've",
    "yall": "you all",
    "pls": "please",
    "ur": "your",
    "u": "you",
    "luv": "love",
    "goodjob": "good job"
}

def separate_merged_words(text):
    """Splits commonly merged words in a given text."""
    for merged, correct in MERGED_WORDS.items():
        text = re.sub(rf"\b{merged}\b", correct, text, flags=re.IGNORECASE)
    return text

# %%
nepali_stop_words = ["ma", "timi", "tapai", "hami", "usle", "uniharule", "yo", "tyo", "kunai", "ek", "dui", "tin", "euta", "duita", "kehi", "thuprai", "sabai",
"ra", "athawa", "tara", "jastai", "bhane", "ani", "kina ki",
"ma", "bata", "samma", "sanga", "pachhi", "agadi",
"cha", "chha", "thiye", "huncha", "bhayo", "garna",
"ke", "kahile", "kata", "kina", "kasari", "ko", "kasko",
"ho", "ni", "hai", "ta", "le", "nai", "pani", "matra", "dherai", "ki", "raixa"]

# %%
all_stop_words = list(Stopwords) + list(set(nepali_stop_words))

# %%
import re

# Define emoji categories
positive_emojis = [
    "😀", "😃", "😄", "😁", "😆", "😅", "😂", "🤣", "😊", "😇",
    "🙂", "🙃", "😉", "😌", "😍", "🥰", "😘", "😗", "😙", "😚",
    "🤩", "🥳", "💖", "❤️", "💙", "💚", "💛", "💜", "💞", "💕",
    "💓", "💗", "💝", "💟", "👍", "👏", "🤗", "👌", "🙏", "✨", "💯", "🔥", "😎", "✅", "🌟", "☺️", "😋",
    "🌻", "🥹", "♥️", "⭐️", "🫣", "✌️", "❤", "🤭", "❣️", "😝", "🫶🏻", "🤝"
]

negative_emojis = [
    "😞", "😟", "😠", "😡", "😢", "😭", "😣", "😖", "😫", "😩",
    "🥺", "😤", "😥", "😰", "😨", "😧", "😦", "😔", "☹️", "🙁",
    "👎", "💔", "😏", "😕", "😒", "😡", "😏", "🤧", "😴", "🤨", "🥲", "🤬", "🤦🏽", "👿", "😿", "🙄", "🥲"
]

def emoji(review_data):
    # Replace positive emojis
    for emoji in positive_emojis:
        review_data = review_data.replace(emoji, " positiveemoji ")

    # Replace negative emojis
    for emoji in negative_emojis:
        review_data = review_data.replace(emoji, " negativeemoji ")

    return review_data

# %%
import re
import string

def Text_Cleaning(Text):
    if not isinstance(Text, str):  # Check if input is a string
        print(Text)
        return ""  # Return empty string for NaN or non-string values

    # Lowercase the text
    Text = Text.lower()

    # Remove punctuations
    punc = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    Text = Text.translate(punc)

    # Remove numbers
    Text = re.sub(r'\d+', '', Text)

    # Remove possible links
    Text = re.sub(r'https?://\S+|www\.\S+', '', Text)

    # Delete newlines
    Text = re.sub(r'\n', '', Text)

     # Replace emoji with text
    Text = emoji(Text)

    return Text

# %%
df.dropna()
# Out:
#                                                  Product  \
# 0      Moisture Matte Long Stay Lipstick - 2g | Espre...
# 1      ComfySlim 3 in 1 Postpartum Support Recovery B...
# 3      Khadi Natural Hand Cream Milk & Saffron - With...
# 6      Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8      Hoco UPA20 3.5 audio extension cable male to f...
# ...                                                  ...
# 34427  Pebbles Nepal 10 pieces Long Lasting Natural P...
# 34429  Silver Crest Electric Meat Grinder 3 ltr ( 1 Y...
# 34435  Black Waterproof And Windproof Touch Screen Glove
# 34436                              Polar Gown For Ladies
# 34438    KITO Slippers for Men- Kito AH83M- Black Slides
#
#                                                   Review  Rating
# 0      It’s good tara halka fohor deliver garidinu va...       3
# 1      good according to its price.. material chai al...       5
# 3      I ordered this product for my mom and she love...       5
# 6                                        Nice and useful       5
# 8      First of all quick shipping and delivery(recei...       5
# ...                                                  ...     ...
# 34427  ahhh...... tattoo was good hai but lagaune man...       5
# 34429                               Got damaged product.       1
# 34435  windproof and waterproof, warm fur inside. Mat...       5
# 34436  maile magako color  purple aayo pink j gare ni...       1
# 34438  came In a well-packaged condition. Was good as...       5
#
# [16075 rows x 3 columns]

# %%
df["clean_reviews"] = df["Review"].apply(lambda Text: Text_Cleaning(Text))
# Out:
# nan

# %%
import nltk
import nltk.corpus
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
from nltk.stem import WordNetLemmatizer


def Text_Processing(Text):
  Processed_Text = list()
  Lemmatizer = WordNetLemmatizer()
  Text = separate_merged_words(Text)
  Text = remove_emojis(Text)
  normalized_word = normalize_unicode_text(Text)

  # Tokens of Words
  Tokens = nltk.word_tokenize(normalized_word)

  # Removing Stopwords and Lemmatizing Words
  # To reduce noises in our dataset, also to keep it simple and still
  # powerful, we will only omit the word `not` from the list of stopwords

  for word in Tokens:
    if word not in all_stop_words:
      Processed_Text.append(Lemmatizer.lemmatize(word))

  return(" ".join(Processed_Text))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
nltk.download('punkt_tab')

df["cleaned_reviews"] = df["clean_reviews"].apply(lambda Text: Text_Processing(Text))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
filtered_df = pd.read_csv('/content/drive/MyDrive/daraz/words_frequency_normalize_list.csv')
filtered_df.head()
# Out:
#   Devanagari                    Words                    word_counts  \
# 0       अएको     ['aayeko', 'aayako']     {'aayeko': 7, 'aayako': 1}
# 1     अक्दम्      ['aakdam', 'akdam']     {'aakdam': 8, 'akdam': 13}
# 2         अझ        ['aajha', 'ajha']       {'aajha': 1, 'ajha': 10}
# 3        अझै      ['aajhai', 'ajhai']     {'aajhai': 2, 'ajhai': 21}
# 4   अड्किन्छ  ['adkincha', 'adkinxa']  {'adkincha': 1, 'adkinxa': 1}
#
#   Selected_Word
# 0        aayeko
# 1         akdam
# 2          ajha
# 3         ajhai
# 4      adkincha

# %%
len(filtered_df)
# Out:
# 223

# %%
import pandas as pd
import re

# Create a mapping of alternative words to the selected word
replacement_dict = {}
for _, row in filtered_df.iterrows():
    for word in eval(row['Words']):  # Ensure list conversion if stored as a string
        replacement_dict[word] = row['Selected_Word']

# Function to normalize text without removing spaces
def normalize_text(text, replacement_dict):
    words = text.split()  # Split into words to preserve spaces
    normalized_words = [replacement_dict.get(word, word) for word in words]  # Replace only if in dict
    return " ".join(normalized_words)  # Join back with spaces

# Apply normalization
df['normalized_reviews'] = df['cleaned_reviews'].apply(lambda x: normalize_text(x, replacement_dict))

df[['cleaned_reviews', 'normalized_reviews']].head()
# Out:
#                                      cleaned_reviews  \
# 0  ’ good halka fohor deliver garidinu vayo selle...
# 1  good according price material chai ali thin co...
# 3                           ordered product mom love
# 6                                        nice useful
# 8  first quick shipping delivery received day nth...
#
#                                   normalized_reviews
# 0  ’ good halka fohor deliver garidinu vayo selle...
# 1  good according price material chai ali thin co...
# 3                           ordered product mom love
# 6                                        nice useful
# 8  first quick shipping delivery received day nth...

# %%
df.Rating.value_counts()
# Out:
# Rating
# 5    10746
# 1     2213
# 4     1395
# 3     1048
# 2      674
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Product               0
# Review                1
# Rating                0
# clean_reviews         0
# cleaned_reviews       0
# normalized_reviews    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Product               0
# Review                1
# Rating                0
# clean_reviews         0
# cleaned_reviews       0
# normalized_reviews    0
# dtype: int64

# %%
df.dropna()
# Out:
#                                                  Product  \
# 0      Moisture Matte Long Stay Lipstick - 2g | Espre...
# 1      ComfySlim 3 in 1 Postpartum Support Recovery B...
# 3      Khadi Natural Hand Cream Milk & Saffron - With...
# 6      Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8      Hoco UPA20 3.5 audio extension cable male to f...
# ...                                                  ...
# 34427  Pebbles Nepal 10 pieces Long Lasting Natural P...
# 34429  Silver Crest Electric Meat Grinder 3 ltr ( 1 Y...
# 34435  Black Waterproof And Windproof Touch Screen Glove
# 34436                              Polar Gown For Ladies
# 34438    KITO Slippers for Men- Kito AH83M- Black Slides
#
#                                                   Review  Rating  \
# 0      It’s good tara halka fohor deliver garidinu va...       3
# 1      good according to its price.. material chai al...       5
# 3      I ordered this product for my mom and she love...       5
# 6                                        Nice and useful       5
# 8      First of all quick shipping and delivery(recei...       5
# ...                                                  ...     ...
# 34427  ahhh...... tattoo was good hai but lagaune man...       5
# 34429                               Got damaged product.       1
# 34435  windproof and waterproof, warm fur inside. Mat...       5
# 34436  maile magako color  purple aayo pink j gare ni...       1
# 34438  came In a well-packaged condition. Was good as...       5
#
#                                            clean_reviews  \
# 0      it’s good tara halka fohor deliver garidinu va...
# 1      good according to its price   material chai al...
# 3      i ordered this product for my mom and she love...
# 6                                        nice and useful
# 8      first of all quick shipping and delivery recei...
# ...                                                  ...
# 34427  ahhh       tattoo was good hai but lagaune man...
# 34429                               got damaged product
# 34435  windproof and waterproof  warm fur inside  mat...
# 34436  maile magako color  purple aayo pink j gare ni...
# 34438  came in a well packaged condition  was good as...
#
#                                          cleaned_reviews  \
# 0      ’ good halka fohor deliver garidinu vayo selle...
# 1      good according price material chai ali thin co...
# 3                               ordered product mom love
# 6                                            nice useful
# 8      first quick shipping delivery received day nth...
# ...                                                  ...
# 34427  ahhh tattoo good lagaune manxe thiyena bigriyo...
# 34429                                got damaged product
# 34435  windproof waterproof warm fur inside material ...
# 34436  maile magako color purple aayo pink j gare hun...
# 34438  came well packaged condition good new comforta...
#
#                                       normalized_reviews
# 0      ’ good halka fohor deliver garidinu vayo selle...
# 1      good according price material chai ali thin co...
# 3                               ordered product mom love
# 6                                            nice useful
# 8      first quick shipping delivery received day nth...
# ...                                                  ...
# 34427  ahhh tattoo good lagaune manxe thiyena bigriyo...
# 34429                                got damaged product
# 34435  windproof waterproof warm fur inside material ...
# 34436  maile magako color purple aayo pink j gare hun...
# 34438  came well packaged condition good new comforta...
#
# [16075 rows x 6 columns]

# %%
#possible_labels = df.Rating.unique()

# %%
# label_dict = {}
# for index, possible_label in enumerate(possible_labels):
#     label_dict[possible_label] = index

# %%
# label_dict

# %%
# df['label'] = df.Rating.replace(label_dict)

# %%
df.Rating.values
# Out:
# array([3, 5, 5, ..., 5, 1, 5])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(df.index.values,
                                                  df.Rating.values,
                                                  test_size=0.15,
                                                  random_state=17,
                                                  stratify=df.Rating.values)

# %%
y_train[0]
# Out:
# np.int64(5)

# %%
df['data_type'] = ['not_set']*df.shape[0]

# %%
df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

# %%
df.groupby(['Rating', 'data_type']).count()
# Out:
#                   Product  Review  clean_reviews  cleaned_reviews  \
# Rating data_type
# 1      train         1881    1880           1881             1881
#        val            332     332            332              332
# 2      train          573     573            573              573
#        val            101     101            101              101
# 3      train          891     891            891              891
#        val            157     157            157              157
# 4      train         1185    1185           1185             1185
#        val            210     210            210              210
# 5      train         9134    9134           9134             9134
#        val           1612    1612           1612             1612
#
#                   normalized_reviews
# Rating data_type
# 1      train                    1881
#        val                       332
# 2      train                     573
#        val                       101
# 3      train                     891
#        val                       157
# 4      train                    1185
#        val                       210
# 5      train                    9134
#        val                      1612

# %%
from transformers import BertTokenizer
from torch.utils.data import TensorDataset

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased',  do_lower_case=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
df.data_type == 'train'
# Out:
# 0        False
# 1         True
# 3         True
# 6         True
# 8        False
#          ...
# 34427     True
# 34429     True
# 34435     True
# 34436     True
# 34438     True
# Name: data_type, Length: 16076, dtype: bool

# %%
df
# Out:
#                                                  Product  \
# 0      Moisture Matte Long Stay Lipstick - 2g | Espre...
# 1      ComfySlim 3 in 1 Postpartum Support Recovery B...
# 3      Khadi Natural Hand Cream Milk & Saffron - With...
# 6      Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8      Hoco UPA20 3.5 audio extension cable male to f...
# ...                                                  ...
# 34427  Pebbles Nepal 10 pieces Long Lasting Natural P...
# 34429  Silver Crest Electric Meat Grinder 3 ltr ( 1 Y...
# 34435  Black Waterproof And Windproof Touch Screen Glove
# 34436                              Polar Gown For Ladies
# 34438    KITO Slippers for Men- Kito AH83M- Black Slides
#
#                                                   Review  Rating  \
# 0      It’s good tara halka fohor deliver garidinu va...       3
# 1      good according to its price.. material chai al...       5
# 3      I ordered this product for my mom and she love...       5
# 6                                        Nice and useful       5
# 8      First of all quick shipping and delivery(recei...       5
# ...                                                  ...     ...
# 34427  ahhh...... tattoo was good hai but lagaune man...       5
# 34429                               Got damaged product.       1
# 34435  windproof and waterproof, warm fur inside. Mat...       5
# 34436  maile magako color  purple aayo pink j gare ni...       1
# 34438  came In a well-packaged condition. Was good as...       5
#
#                                            clean_reviews  \
# 0      it’s good tara halka fohor deliver garidinu va...
# 1      good according to its price   material chai al...
# 3      i ordered this product for my mom and she love...
# 6                                        nice and useful
# 8      first of all quick shipping and delivery recei...
# ...                                                  ...
# 34427  ahhh       tattoo was good hai but lagaune man...
# 34429                               got damaged product
# 34435  windproof and waterproof  warm fur inside  mat...
# 34436  maile magako color  purple aayo pink j gare ni...
# 34438  came in a well packaged condition  was good as...
#
#                                          cleaned_reviews  \
# 0      ’ good halka fohor deliver garidinu vayo selle...
# 1      good according price material chai ali thin co...
# 3                               ordered product mom love
# 6                                            nice useful
# 8      first quick shipping delivery received day nth...
# ...                                                  ...
# 34427  ahhh tattoo good lagaune manxe thiyena bigriyo...
# 34429                                got damaged product
# 34435  windproof waterproof warm fur inside material ...
# 34436  maile magako color purple aayo pink j gare hun...
# 34438  came well packaged condition good new comforta...
#
#                                       normalized_reviews data_type
# 0      ’ good halka fohor deliver garidinu vayo selle...       val
# 1      good according price material chai ali thin co...     train
# 3                               ordered product mom love     train
# 6                                            nice useful     train
# 8      first quick shipping delivery received day nth...       val
# ...                                                  ...       ...
# 34427  ahhh tattoo good lagaune manxe thiyena bigriyo...     train
# 34429                                got damaged product     train
# 34435  windproof waterproof warm fur inside material ...     train
# 34436  maile magako color purple aayo pink j gare hun...     train
# 34438  came well packaged condition good new comforta...     train
#
# [16076 rows x 7 columns]

# %%
def Labelling(Rows):
  if(Rows["Rating"] > 3.0):
    Label = "Positive"
  elif(Rows["Rating"] < 3.0):
    Label = "Negative"
  else:
    Label = "Neutral"
  return Label

# %%
df["sentiment"] = df.apply(Labelling, axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder

Encoder = LabelEncoder()
df["label"] = Encoder.fit_transform(df["sentiment"])

# %%
df.head()
# Out:
#                                              Product  \
# 0  Moisture Matte Long Stay Lipstick - 2g | Espre...
# 1  ComfySlim 3 in 1 Postpartum Support Recovery B...
# 3  Khadi Natural Hand Cream Milk & Saffron - With...
# 6  Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8  Hoco UPA20 3.5 audio extension cable male to f...
#
#                                               Review  Rating  \
# 0  It’s good tara halka fohor deliver garidinu va...       3
# 1  good according to its price.. material chai al...       5
# 3  I ordered this product for my mom and she love...       5
# 6                                    Nice and useful       5
# 8  First of all quick shipping and delivery(recei...       5
#
#                                        clean_reviews  \
# 0  it’s good tara halka fohor deliver garidinu va...
# 1  good according to its price   material chai al...
# 3  i ordered this product for my mom and she love...
# 6                                    nice and useful
# 8  first of all quick shipping and delivery recei...
#
#                                      cleaned_reviews  \
# 0  ’ good halka fohor deliver garidinu vayo selle...
# 1  good according price material chai ali thin co...
# 3                           ordered product mom love
# 6                                        nice useful
# 8  first quick shipping delivery received day nth...
#
#                                   normalized_reviews data_type sentiment  \
# 0  ’ good halka fohor deliver garidinu vayo selle...       val   Neutral
# 1  good according price material chai ali thin co...     train  Positive
# 3                           ordered product mom love     train  Positive
# 6                                        nice useful     train  Positive
# 8  first quick shipping delivery received day nth...       val  Positive
#
#    label
# 0      1
# 1      2
# 3      2
# 6      2
# 8      2

# %%
df[df.data_type=='train'].normalized_reviews.values
# Out:
# array(['good according price material chai ali thin compared comfortable',
#        'ordered product mom love', 'nice useful', ...,
#        'windproof waterproof warm fur inside material quality decent feel premium',
#        'maile magako color purple aayo pink j gare hune jasto gare hune n',
#        'came well packaged condition good new comfortable wear pricier side still affordable compared original nike filum adidas comfortable look cool sock matter'],
#       dtype=object)

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].normalized_reviews.values,
    add_special_tokens=True,
    return_attention_mask=True,
    padding='max_length',
    truncation=True,
    max_length=256,
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type=='val'].normalized_reviews.values,
    add_special_tokens=True,
    return_attention_mask=True,
    padding='max_length',
    truncation=True,
    max_length=256,
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type=='val'].label.values)

# %%
labels_train
# Out:
# tensor([2, 2, 2,  ..., 2, 0, 2])

# %%
from torch.utils.data import TensorDataset
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)

# %%
len(dataset_train)
# Out:
# 13664

# %%
len(dataset_val)
# Out:
# 2412

# %%
from transformers import BertForSequenceClassification

# %%
possible_labels = df.label.unique()
label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# %%
batch_size = 16

dataloader_train = DataLoader(dataset_train,
                              sampler=RandomSampler(dataset_train),
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val,
                                   sampler=SequentialSampler(dataset_val),
                                   batch_size=batch_size)

# %%
from torch.optim import AdamW
from transformers import get_linear_schedule_with_warmup

# %%
optimizer = AdamW(model.parameters(),
                  lr=1e-5,
                  eps=1e-8)

# %%
epochs = 3

scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
import numpy as np

# %%
from sklearn.metrics import f1_score

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import numpy as np
import torch
from tqdm import tqdm

def compute_metrics(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    accuracy = accuracy_score(labels_flat, preds_flat)
    precision = precision_score(labels_flat, preds_flat, average='weighted', zero_division=0)
    recall = recall_score(labels_flat, preds_flat, average='weighted', zero_division=0)
    f1 = f1_score(labels_flat, preds_flat, average='weighted')

    print("Classification Report:")
    print(classification_report(labels_flat, preds_flat, zero_division=0))

    return accuracy, precision, recall, f1

# %%
def evaluate(dataloader_val):
    model.eval()
    loss_val_total = 0
    predictions, true_vals = [], []

    for batch in dataloader_val:
        batch = tuple(b.to(device) for b in batch)
        inputs = {'input_ids': batch[0],
                  'attention_mask': batch[1],
                  'labels': batch[2]}

        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)

    loss_val_avg = loss_val_total / len(dataloader_val)
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)

    return loss_val_avg, predictions, true_vals

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
from tqdm import tqdm

for epoch in range(1, epochs + 1):
    model.train()
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc=f'Epoch {epoch}', leave=False, mininterval=2)

    for batch in progress_bar:
        model.zero_grad()
        batch = tuple(b.to(device) for b in batch)

        inputs = {
            'input_ids': batch[0],
            'attention_mask': batch[1],
            'labels': batch[2]
        }

        outputs = model(**inputs)
        loss = outputs.loss
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        progress_bar.set_postfix({'training_loss': f'{loss.item():.3f}'})

    # Save model
    torch.save(model.state_dict(), f'/content/drive/MyDrive/daraz/new-english-bert/finetuned_BERT_epoch_{epoch}.model')

    tqdm.write(f'\nEpoch {epoch}')
    loss_train_avg = loss_train_total / len(dataloader_train)
    tqdm.write(f'Training loss: {loss_train_avg:.4f}')

    # Validation
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    accuracy, precision, recall, f1 = compute_metrics(predictions, true_vals)

    tqdm.write(f'Validation loss: {val_loss:.4f}')
    tqdm.write(f'Accuracy: {accuracy:.4f}')
    tqdm.write(f'Precision: {precision:.4f}')
    tqdm.write(f'Recall: {recall:.4f}')
    tqdm.write(f'F1 Score (Weighted): {f1:.4f}')
# Out:
# Epoch 1
# Training loss: 0.3480
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79       433
#            1       0.56      0.14      0.22       157
#            2       0.93      0.94      0.93      1822
#
#     accuracy                           0.87      2412
#    macro avg       0.74      0.65      0.65      2412
# weighted avg       0.87      0.87      0.86      2412
#
# Validation loss: 0.3444
# Accuracy: 0.8748
# Precision: 0.8656
# Recall: 0.8748
# F1 Score (Weighted): 0.8604
# Epoch 2
# Training loss: 0.2829
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79       433
#            1       0.45      0.28      0.35       157
#            2       0.94      0.93      0.93      1822
#
#     accuracy                           0.88      2412
#    macro avg       0.71      0.69      0.69      2412
# weighted avg       0.87      0.88      0.87      2412
#
# Validation loss: 0.3460
# Accuracy: 0.8756
# Precision: 0.8688
# Recall: 0.8756
# F1 Score (Weighted): 0.8703
# Epoch 3
# Training loss: 0.2614
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79       433
#            1       0.45      0.28      0.35       157
#            2       0.94      0.93      0.93      1822
#
#     accuracy                           0.88      2412
#    macro avg       0.71      0.69      0.69      2412
# weighted avg       0.87      0.88      0.87      2412
#
# Validation loss: 0.3460
# Accuracy: 0.8756
# Precision: 0.8688
# Recall: 0.8756
# F1 Score (Weighted): 0.8703
