# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import pandas as pd
from tqdm.notebook import tqdm

# %%
df = pd.read_excel('/content/drive/MyDrive/daraz/Share_Review.xlsx', names=['Product', 'Review', 'Rating'])
df.head()
# Out:
#                                              Product  \
# 0  Moisture Matte Long Stay Lipstick - 2g | Espre...
# 1                          Spandex Suspender For Men
# 2                    Cosmetic Organizer/ Storage Box
# 3  Khadi Natural Hand Cream Milk & Saffron - With...
# 4               Newari Shahi Pulao Basmati Rice 5 Kg
#
#                                               Review  Rating
# 0                                                  -       3
# 1                                                  -       5
# 2                                                  -       4
# 3  I ordered this product for my mom and she love...       5
# 4                                                  -       5

# %%
df.Rating.value_counts()
# Out:
# Rating
# 5    24617
# 4     3640
# 1     2960
# 3     2169
# 2     1055
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Product    0
# Review     1
# Rating     0
# dtype: int64

# %%
df = df[~df["Review"].isin(["", "-"])]

# %%
df.Rating.value_counts()
# Out:
# Rating
# 5    10966
# 1     2279
# 4     1436
# 3     1062
# 2      694
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Product    0
# Review     1
# Rating     0
# dtype: int64

# %%
df.dropna()
# Out:
#                                                  Product  \
# 3      Khadi Natural Hand Cream Milk & Saffron - With...
# 6      Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8      Hoco UPA20 3.5 audio extension cable male to f...
# 9      Grohe  Household ABS Pressurized Toilet Spray ...
# 13     The Power Of Your Subconscious Mind By Joseph ...
# ...                                                  ...
# 34427  Pebbles Nepal 10 pieces Long Lasting Natural P...
# 34429  Silver Crest Electric Meat Grinder 3 ltr ( 1 Y...
# 34435  Black Waterproof And Windproof Touch Screen Glove
# 34436                              Polar Gown For Ladies
# 34438    KITO Slippers for Men- Kito AH83M- Black Slides
#
#                                                   Review  Rating
# 3      I ordered this product for my mom and she love...       5
# 6                                        Nice and useful       5
# 8      First of all quick shipping and delivery(recei...       5
# 9      Can’t be original. Looks like chrome plated in...       4
# 13                  First 30 Book pages aren't on order.       1
# ...                                                  ...     ...
# 34427  ahhh...... tattoo was good hai but lagaune man...       5
# 34429                               Got damaged product.       1
# 34435  windproof and waterproof, warm fur inside. Mat...       5
# 34436  maile magako color  purple aayo pink j gare ni...       1
# 34438  came In a well-packaged condition. Was good as...       5
#
# [16436 rows x 3 columns]

# %%
#possible_labels = df.Rating.unique()

# %%
# label_dict = {}
# for index, possible_label in enumerate(possible_labels):
#     label_dict[possible_label] = index

# %%
# label_dict

# %%
# df['label'] = df.Rating.replace(label_dict)

# %%
df.head()
# Out:
#                                               Product  \
# 3   Khadi Natural Hand Cream Milk & Saffron - With...
# 6   Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8   Hoco UPA20 3.5 audio extension cable male to f...
# 9   Grohe  Household ABS Pressurized Toilet Spray ...
# 13  The Power Of Your Subconscious Mind By Joseph ...
#
#                                                Review  Rating
# 3   I ordered this product for my mom and she love...       5
# 6                                     Nice and useful       5
# 8   First of all quick shipping and delivery(recei...       5
# 9   Can’t be original. Looks like chrome plated in...       4
# 13               First 30 Book pages aren't on order.       1

# %%
df.Rating.values
# Out:
# array([5, 5, 5, ..., 5, 1, 5])

# %%
import re
import string

def Text_Cleaning(Text):
    if not isinstance(Text, str):  # Check if input is a string
        print(Text)
        return ""  # Return empty string for NaN or non-string values

    # Lowercase the text
    Text = Text.lower()

    # Remove punctuations
    punc = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    Text = Text.translate(punc)

    # Remove numbers
    Text = re.sub(r'\d+', '', Text)

    # Remove possible links
    Text = re.sub(r'https?://\S+|www\.\S+', '', Text)

    # Delete newlines
    Text = re.sub(r'\n', '', Text)

    return Text

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import words, wordnet as wn

# Download necessary resources
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("words")

# Initialize lemmatizer and spell checker
Lemmatizer = WordNetLemmatizer()

# Load English words dictionary
english_vocab = set(words.words())

# Define stopwords (excluding "not")
Stopwords = set(nltk.corpus.stopwords.words("english")) - {"not"}

def is_strictly_english(word):
    """Check if a word is a valid English word using NLTK dictionary and WordNet."""
    return word.lower() in english_vocab or bool(wn.synsets(word))


def Text_Processing(Text):
    """Processes text by removing stopwords, correcting spelling, and lemmatizing words."""
    Processed_Text = []

    # Tokenization
    Tokens = nltk.word_tokenize(Text)

    for word in Tokens:
        if word not in Stopwords:  # Remove stopwords
            # Correct spelling if not strictly English
            # corrected_word = correct_spelling(word) if not is_strictly_english(word) else word
            # Lemmatization
            lemmatized_word = Lemmatizer.lemmatize(word)
            Processed_Text.append(lemmatized_word)

    return " ".join(Processed_Text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
df["clean_reviews"] = df["Review"].apply(lambda Text: Text_Cleaning(Text))
# Out:
# nan

# %%
import nltk
nltk.download('punkt_tab')

df["cleaned_reviews"] = df["clean_reviews"].apply(lambda Text: Text_Processing(Text))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(df.index.values,
                                                  df.Rating.values,
                                                  test_size=0.15,
                                                  random_state=17,
                                                  stratify=df.Rating.values)

# %%
y_train[0]
# Out:
# np.int64(4)

# %%
df['data_type'] = ['not_set']*df.shape[0]

# %%
df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

# %%
df.groupby(['Rating', 'data_type']).count()
# Out:
#                   Product  Review  clean_reviews  cleaned_reviews
# Rating data_type
# 1      train         1937    1936           1937             1937
#        val            342     342            342              342
# 2      train          590     590            590              590
#        val            104     104            104              104
# 3      train          903     903            903              903
#        val            159     159            159              159
# 4      train         1220    1220           1220             1220
#        val            216     216            216              216
# 5      train         9321    9321           9321             9321
#        val           1645    1645           1645             1645

# %%
from transformers import BertTokenizer
from torch.utils.data import TensorDataset

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased',  do_lower_case=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
df.data_type == 'train'
# Out:
# 3         True
# 6         True
# 8         True
# 9         True
# 13        True
#          ...
# 34427     True
# 34429     True
# 34435    False
# 34436     True
# 34438     True
# Name: data_type, Length: 16437, dtype: bool

# %%
df
# Out:
#                                                  Product  \
# 3      Khadi Natural Hand Cream Milk & Saffron - With...
# 6      Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8      Hoco UPA20 3.5 audio extension cable male to f...
# 9      Grohe  Household ABS Pressurized Toilet Spray ...
# 13     The Power Of Your Subconscious Mind By Joseph ...
# ...                                                  ...
# 34427  Pebbles Nepal 10 pieces Long Lasting Natural P...
# 34429  Silver Crest Electric Meat Grinder 3 ltr ( 1 Y...
# 34435  Black Waterproof And Windproof Touch Screen Glove
# 34436                              Polar Gown For Ladies
# 34438    KITO Slippers for Men- Kito AH83M- Black Slides
#
#                                                   Review  Rating  \
# 3      I ordered this product for my mom and she love...       5
# 6                                        Nice and useful       5
# 8      First of all quick shipping and delivery(recei...       5
# 9      Can’t be original. Looks like chrome plated in...       4
# 13                  First 30 Book pages aren't on order.       1
# ...                                                  ...     ...
# 34427  ahhh...... tattoo was good hai but lagaune man...       5
# 34429                               Got damaged product.       1
# 34435  windproof and waterproof, warm fur inside. Mat...       5
# 34436  maile magako color  purple aayo pink j gare ni...       1
# 34438  came In a well-packaged condition. Was good as...       5
#
#                                            clean_reviews  \
# 3      i ordered this product for my mom and she love...
# 6                                        nice and useful
# 8      first of all quick shipping and delivery recei...
# 9      can’t be original  looks like chrome plated in...
# 13                    first  book pages aren t on order
# ...                                                  ...
# 34427  ahhh       tattoo was good hai but lagaune man...
# 34429                               got damaged product
# 34435  windproof and waterproof  warm fur inside  mat...
# 34436  maile magako color  purple aayo pink j gare ni...
# 34438  came in a well packaged condition  was good as...
#
#                                          cleaned_reviews data_type
# 3                               ordered product mom love     train
# 6                                            nice useful     train
# 8      first quick shipping delivery received day nth...     train
# 9             ’ original look like chrome plated plastic     train
# 13                                 first book page order     train
# ...                                                  ...       ...
# 34427  ahhh tattoo good hai lagaune manxe thiyena big...     train
# 34429                                got damaged product     train
# 34435  windproof waterproof warm fur inside material ...       val
# 34436  maile magako color purple aayo pink j gare ni ...     train
# 34438  came well packaged condition good new comforta...     train
#
# [16437 rows x 6 columns]

# %%
def Labelling(Rows):
  if(Rows["Rating"] > 3.0):
    Label = "Positive"
  elif(Rows["Rating"] < 3.0):
    Label = "Negative"
  else:
    Label = "Neutral"
  return Label

# %%
df["sentiment"] = df.apply(Labelling, axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder

Encoder = LabelEncoder()
df["label"] = Encoder.fit_transform(df["sentiment"])

# %%
df.head()
# Out:
#                                               Product  \
# 3   Khadi Natural Hand Cream Milk & Saffron - With...
# 6   Kitchen Cabinet Doors Hanging Plastic Trash Mu...
# 8   Hoco UPA20 3.5 audio extension cable male to f...
# 9   Grohe  Household ABS Pressurized Toilet Spray ...
# 13  The Power Of Your Subconscious Mind By Joseph ...
#
#                                                Review  Rating  \
# 3   I ordered this product for my mom and she love...       5
# 6                                     Nice and useful       5
# 8   First of all quick shipping and delivery(recei...       5
# 9   Can’t be original. Looks like chrome plated in...       4
# 13               First 30 Book pages aren't on order.       1
#
#                                         clean_reviews  \
# 3   i ordered this product for my mom and she love...
# 6                                     nice and useful
# 8   first of all quick shipping and delivery recei...
# 9   can’t be original  looks like chrome plated in...
# 13                 first  book pages aren t on order
#
#                                       cleaned_reviews data_type sentiment  \
# 3                            ordered product mom love     train  Positive
# 6                                         nice useful     train  Positive
# 8   first quick shipping delivery received day nth...     train  Positive
# 9          ’ original look like chrome plated plastic     train  Positive
# 13                              first book page order     train  Negative
#
#     label
# 3       2
# 6       2
# 8       2
# 9       2
# 13      0

# %%
df[df.data_type=='train'].cleaned_reviews.values
# Out:
# array(['ordered product mom love', 'nice useful',
#        'first quick shipping delivery received day nthe item bubble wrapped extra safety nthe quality cable good sure last long time negligible volume loss degradation sound quality also sweet thank card included ni would highly recommend seller would definitely shop',
#        ..., 'got damaged product',
#        'maile magako color purple aayo pink j gare ni hune hai jasto gare ni hune n',
#        'came well packaged condition good new comfortable wear pricier side still affordable compared original nike filum adidas comfortable look cool sock matter'],
#       dtype=object)

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].cleaned_reviews.values,
    add_special_tokens=True,
    return_attention_mask=True,
    padding='max_length',
    truncation=True,
    max_length=256,
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type=='val'].cleaned_reviews.values,
    add_special_tokens=True,
    return_attention_mask=True,
    padding='max_length',
    truncation=True,
    max_length=256,
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type=='val'].label.values)

# %%
labels_train
# Out:
# tensor([2, 2, 2,  ..., 0, 0, 2])

# %%
from torch.utils.data import TensorDataset
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)

# %%
len(dataset_train)
# Out:
# 13971

# %%
len(dataset_val)
# Out:
# 2466

# %%
from transformers import BertForSequenceClassification

# %%
possible_labels = df.label.unique()
label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# %%
batch_size = 16

dataloader_train = DataLoader(dataset_train,
                              sampler=RandomSampler(dataset_train),
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val,
                                   sampler=SequentialSampler(dataset_val),
                                   batch_size=batch_size)

# %%
from torch.optim import AdamW
from transformers import get_linear_schedule_with_warmup

# %%
optimizer = AdamW(model.parameters(),
                  lr=1e-5,
                  eps=1e-8)

# %%
epochs = 3

scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
import numpy as np

# %%
from sklearn.metrics import f1_score

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report
import numpy as np
import torch
from tqdm import tqdm

def compute_metrics(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    accuracy = accuracy_score(labels_flat, preds_flat)
    precision = precision_score(labels_flat, preds_flat, average='weighted', zero_division=0)
    recall = recall_score(labels_flat, preds_flat, average='weighted', zero_division=0)
    f1 = f1_score(labels_flat, preds_flat, average='weighted')

    print("Classification Report:")
    print(classification_report(labels_flat, preds_flat, zero_division=0))

    return accuracy, precision, recall, f1

# %%
def evaluate(dataloader_val):
    model.eval()
    loss_val_total = 0
    predictions, true_vals = [], []

    for batch in dataloader_val:
        batch = tuple(b.to(device) for b in batch)
        inputs = {'input_ids': batch[0],
                  'attention_mask': batch[1],
                  'labels': batch[2]}

        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)

    loss_val_avg = loss_val_total / len(dataloader_val)
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)

    return loss_val_avg, predictions, true_vals

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
from tqdm import tqdm

for epoch in range(1, epochs + 1):
    model.train()
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc=f'Epoch {epoch}', leave=False, mininterval=2)

    for batch in progress_bar:
        model.zero_grad()
        batch = tuple(b.to(device) for b in batch)

        inputs = {
            'input_ids': batch[0],
            'attention_mask': batch[1],
            'labels': batch[2]
        }

        outputs = model(**inputs)
        loss = outputs.loss
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        progress_bar.set_postfix({'training_loss': f'{loss.item():.3f}'})

    # Save model
    torch.save(model.state_dict(), f'/content/drive/MyDrive/daraz/new-english-bert/finetuned_BERT_epoch_{epoch}.model')

    tqdm.write(f'\nEpoch {epoch}')
    loss_train_avg = loss_train_total / len(dataloader_train)
    tqdm.write(f'Training loss: {loss_train_avg:.4f}')

    # Validation
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    accuracy, precision, recall, f1 = compute_metrics(predictions, true_vals)

    tqdm.write(f'Validation loss: {val_loss:.4f}')
    tqdm.write(f'Accuracy: {accuracy:.4f}')
    tqdm.write(f'Precision: {precision:.4f}')
    tqdm.write(f'Recall: {recall:.4f}')
    tqdm.write(f'F1 Score (Weighted): {f1:.4f}')
# Out:
# Epoch 1
# Training loss: 0.4497
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.86      0.76       446
#            1       0.50      0.02      0.04       159
#            2       0.92      0.93      0.92      1861
#
#     accuracy                           0.86      2466
#    macro avg       0.70      0.60      0.57      2466
# weighted avg       0.85      0.86      0.84      2466
#
# Validation loss: 0.3985
# Accuracy: 0.8613
# Precision: 0.8466
# Recall: 0.8613
# F1 Score (Weighted): 0.8376
# Epoch 2
# Training loss: 0.3464
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.84      0.78       446
#            1       0.44      0.07      0.12       159
#            2       0.91      0.94      0.93      1861
#
#     accuracy                           0.87      2466
#    macro avg       0.69      0.62      0.61      2466
# weighted avg       0.85      0.87      0.85      2466
#
# Validation loss: 0.3899
# Accuracy: 0.8686
# Precision: 0.8486
# Recall: 0.8686
# F1 Score (Weighted): 0.8489
# Epoch 3
# Training loss: 0.2917
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79       446
#            1       0.47      0.23      0.31       159
#            2       0.92      0.94      0.93      1861
#
#     accuracy                           0.87      2466
#    macro avg       0.71      0.67      0.67      2466
# weighted avg       0.86      0.87      0.86      2466
#
# Validation loss: 0.3743
# Accuracy: 0.8731
# Precision: 0.8615
# Recall: 0.8731
# F1 Score (Weighted): 0.8641
