# %%
from collections import defaultdict
import pandas as pd
import unicodedata
from metaphone import doublemetaphone

# Load the CSV file
df = pd.read_csv("files/multi_words_devnagri_root.csv")

# %%
df.head()
# Out:
#      Words Devanagari     Root
# 0  raamrai     राम्रै   राम्रा
# 1   raamro     राम्रो   राम्रा
# 2    fohor      फोहोर    फोहोर
# 3    xodyo     छोड्यो   छोड्यो
# 4   sidhai       सिधै     सिधा

# %%
# Function to normalize text to ASCII
def normalize_to_ascii(word):
    return ''.join(
        (c for c in unicodedata.normalize('NFD', word) if unicodedata.category(c) != 'Mn')
    ).encode('ascii', 'ignore').decode('ascii')

# Dictionary to group both Romanized and Devanagari words
nepali_phonetic_groups = defaultdict(lambda: {"Words": set(), "Root": set()})

# Iterate over rows to group by Double Metaphone
for _, row in df.iterrows():
    roman = row["Words"]
    dev = row["Root"]
    normalized_word = normalize_to_ascii(roman)
    primary_code, secondary_code = doublemetaphone(normalized_word)

    # Choose primary code if available, otherwise fallback to secondary
    phonetic_code = primary_code or secondary_code

    if phonetic_code and len(phonetic_code) > 0:
        nepali_phonetic_groups[phonetic_code]["Words"].add(roman)
        nepali_phonetic_groups[phonetic_code]["Root"].add(dev)

# Convert sets to lists and print the results
for phonetic_code, groups in nepali_phonetic_groups.items():
    romanized_list = list(groups["Words"])
    devnagari_list = list(groups["Root"])
    print(f"Phonetic Code: {phonetic_code} -> Romanized: {romanized_list}, Root: {devnagari_list}")
# Out:
# Phonetic Code: RMR -> Romanized: ['raamrai', 'ramro', 'raamro', 'ramroi', 'ramroo'], Root: ['राम्रो', 'राम्रा', ' राम्रै', ' राम्रा', ' राम्रो']
# Phonetic Code: FHR -> Romanized: ['fohor'], Root: ['फोहोर']
# Phonetic Code: ST -> Romanized: ['xodyo', 'sadaie', 'sadhai', 'sidhai', 'siddai'], Root: [' छोड्यो', ' सिधा ', 'सधै', ' सिधा']
# Phonetic Code: TKNKS -> Romanized: ['dekhinx', 'dekinxa'], Root: ['देखिन्छ']
# Phonetic Code: FR -> Romanized: ['vayera', 'vayeraw', 'vaera', 'vayerw', 'vayara'], Root: [' भएर']
# Phonetic Code: PR -> Romanized: ['paryoo', 'paurai', 'pariyo', 'purae', 'pareyo', 'bhayera', 'bhaera', 'paryo', 'puraie'], Root: [' भएर', ' पर्यो', ' पुरा', 'पुरै']
# Phonetic Code: MLTN -> Romanized: ['mildaina'], Root: ['मिल्दैन']
# Phonetic Code: A0 -> Romanized: ['authyo', 'aauthyo'], Root: ['आउथ्यो']
# Phonetic Code: KRK -> Romanized: ['koreko', 'gariyeko', 'garieko'], Root: ['कोरेको', 'गरीएको']
# Phonetic Code: PN -> Romanized: ['bhannuu', 'paaunu', 'bhannu', 'pugne', 'paunu'], Root: [' पुग्ने', 'पुग्ने', 'पाउनु', 'भन्नू']
# Phonetic Code: MJL -> Romanized: ['majaley', 'majale', 'majjala', 'majjale', 'majjaale'], Root: ['मजाले', 'मज्जाले']
# Phonetic Code: PKR -> Romanized: ['bhakkhar'], Root: ['भक्खर्']
# Phonetic Code: FKR -> Romanized: ['vakkhar'], Root: ['भक्खर्']
# Phonetic Code: FS -> Romanized: ['phasiyo', 'fasiyo'], Root: ['फसियो']
# Phonetic Code: LJ -> Romanized: ['laaja', 'laaj', 'lagiyo'], Root: ['लाज', 'लगियो', ' लगियो']
# Phonetic Code: PKM -> Romanized: ['paaekomaa', 'payekoma'], Root: ['पाएकोमा']
# Phonetic Code: PKS -> Romanized: ['pauxa', 'paxi'], Root: ['पाउछ', 'पछी', 'पछि']
# Phonetic Code: PK -> Romanized: ['pachhi', 'bhayako', 'bhaeko', 'pauchha'], Root: [' पाउछ', 'पछी', 'भयको', 'भएको']
# Phonetic Code: JST -> Romanized: ['jastoh', 'jasto'], Root: ['जस्तो', ' जस्तो']
# Phonetic Code: RKS -> Romanized: ['raix', 'raixa', 'raex'], Root: [' रैछ', 'रैछ']
# Phonetic Code: RX -> Romanized: ['raichha', 'raichhaa'], Root: ['रैछ']
# Phonetic Code: HNKS -> Romanized: ['hunexw', 'hunxa', 'hunexa'], Root: ['हुनेछ', 'हुन्छ']
# Phonetic Code: P -> Romanized: ['bayo', 'bhayo', 'bhayoo', 'bho'], Root: ['भो', ' भयो', 'भयो']
# Phonetic Code: F -> Romanized: ['vayo', 'vayoo'], Root: ['भयो']
# Phonetic Code: AT -> Romanized: ['aati', 'eauta', 'yauta', 'aadha', 'ati'], Root: ['एउटा', 'आधा', 'अती']
# Phonetic Code: P0 -> Romanized: ['pauthiyo'], Root: ['पाउथियो', ' पाउथियो']
# Phonetic Code: M0 -> Romanized: ['mithoooooooooooooo', 'mitho'], Root: [' मिठो']
# Phonetic Code: FNT -> Romanized: ['vandaa', 'vanda'], Root: ['भन्दा', ' भन्दा']
# Phonetic Code: KLK -> Romanized: ['khuuleko', 'khuleko'], Root: [' खुलेको']
# Phonetic Code: KSNN -> Romanized: ["'xain'", "'xaain'"], Root: [' छैन']
# Phonetic Code: KSN -> Romanized: ["'xhaina'", "'xainw'", "'xaina'", "'xoina'", "'xaena'", "'xiana'"], Root: [' छैन']
# Phonetic Code: LK -> Romanized: ['lagyo'], Root: [' लाग्यो', 'लाग्यो']
# Phonetic Code: PKRK -> Romanized: ['bigreka'], Root: [' बिग्रेका']
# Phonetic Code: KSR -> Romanized: ['kasri', 'kasari'], Root: ['कसरी', ' कसरी']
# Phonetic Code: TKX -> Romanized: ['tikcha'], Root: [' टिक्छ']
# Phonetic Code: TKKS -> Romanized: ['tikxa'], Root: [' टिक्छ']
# Phonetic Code: TKR -> Romanized: ['dekhayar', 'dekhayara'], Root: [' देखायर', 'देखायर']
# Phonetic Code: TKK -> Romanized: ['dhekako', 'dekako'], Root: ['देखाको']
# Phonetic Code: AKTM -> Romanized: ['ekdamei', 'ekdaaam', 'akdamai', 'ekdhaam', 'ekdamaii', 'ekdamm', 'ekdem', 'ekdami', 'eakdum', 'akdam', 'yakdam'], Root: [' एकदम', 'एकदमै', ' एकदमै', 'एकदम']
# Phonetic Code: ATKM -> Romanized: ['edkam'], Root: [' एकदम']
# Phonetic Code: TNX -> Romanized: ['dincha'], Root: [' दिन्छ']
# Phonetic Code: MM -> Romanized: ['mamu', 'maamu'], Root: ['मामू', ' मामू']
# Phonetic Code: KTR -> Romanized: ['khatra', 'khatraa'], Root: [' खत्रा', 'खत्रा']
# Phonetic Code: S -> Romanized: ['xyaa'], Root: [' छ्या']
# Phonetic Code: AK -> Romanized: ['aayeko', 'aayko', 'aayako', 'aauchha'], Root: [' आएको', 'आउछ', 'आएको']
# Phonetic Code: TR -> Romanized: ['dherae', 'dheraiii', 'taraw', 'dharaiiiiiiiiiiii', 'twrw'], Root: ['तर', 'धेरै', ' तर', ' धेरै']
# Phonetic Code: AP -> Romanized: ['aabw', 'aaba'], Root: [' आब', 'आब']
# Phonetic Code: FK -> Romanized: ['vayko', 'vayeko', 'vayako'], Root: ['भयको', 'भएको', ' भयको']
# Phonetic Code: HNX -> Romanized: ['hunchha'], Root: [' हुन्छ']
# Phonetic Code: ANXR -> Romanized: ['aanushar', 'anushar'], Root: [' अनुशार', 'अनुशार']
# Phonetic Code: TNPT -> Romanized: ['dhanyabaad', 'dhanyabad', 'dhanyabadh'], Root: ['धन्यबाद']
# Phonetic Code: SN -> Romanized: ['xain', 'xoina', 'xiana', 'xainw', 'xhaina'], Root: ['छैन']
# Phonetic Code: TST -> Romanized: ['testaee', 'testai', 'testaiii'], Root: ['तेस्तै']
# Phonetic Code: PTR -> Romanized: ['bhitra'], Root: [' भित्र']
# Phonetic Code: FTK -> Romanized: ['phatako'], Root: [' पठाको']
# Phonetic Code: K -> Romanized: ['khiyaa', 'khiya'], Root: [' खिया', 'खिया']
# Phonetic Code: L -> Romanized: ['laai', 'lae'], Root: [' लै', 'लै']
# Phonetic Code: M -> Romanized: ['ma', 'mwh', 'maa', 'mah'], Root: [' म', 'म']
# Phonetic Code: ARK -> Romanized: ['arko', 'aarkho'], Root: ['अर्को', ' अर्को']
# Phonetic Code: TNT -> Romanized: ['dhanyawad'], Root: [' धन्यबाद']
# Phonetic Code: KRX -> Romanized: ['garcha', 'garchha'], Root: [' गर्छ']
# Phonetic Code: ATN -> Romanized: ['audena', 'audina'], Root: [' आउडीन', 'आउडीन']
# Phonetic Code: AX -> Romanized: ['aucha', 'aaucha'], Root: [' आउछ', 'आउछ']
# Phonetic Code: AS -> Romanized: ['azai'], Root: [' अझै']
# Phonetic Code: KRT -> Romanized: ['gardae', 'gardai'], Root: ['गर्दै', ' गर्दै']
# Phonetic Code: PRX -> Romanized: ['parecha'], Root: [' परेछ']
# Phonetic Code: P0X -> Romanized: ['pathauchu', 'pathayecha'], Root: ['पठाएछ', 'पठाउछु']
# Phonetic Code: TMM -> Romanized: ['dammm', 'dammmi'], Root: ['दाम', 'दामी']
# Phonetic Code: HN -> Romanized: ['hunay', 'hune'], Root: ['हुने']
# Phonetic Code: 0N -> Romanized: ['thyeena', 'theyena'], Root: ['थिएन']
# Phonetic Code: 0K -> Romanized: ['thikai', 'thekai', 'thikei', 'theekai'], Root: ['ठिकै']
# Phonetic Code: RKR -> Romanized: ['rakhera', 'rakhaira', 'rakhayera'], Root: ['राखेर']
# Phonetic Code: KRR -> Romanized: ['garer', 'garyara'], Root: ['गरेर']
# Phonetic Code: KS -> Romanized: ['khassai', 'kassai'], Root: ['खास्सै']
# Phonetic Code: KH -> Romanized: ['cahii', 'chhahi'], Root: ['चाही']
# Phonetic Code: NLN -> Romanized: ['naline'], Root: ['नलीने']
# Phonetic Code: KRN -> Romanized: ['garney', 'garne'], Root: ['गर्ने']
# Phonetic Code: H -> Romanized: ['haii', 'hae'], Root: ['है']
# Phonetic Code: TNKS -> Romanized: ['dinxa'], Root: ['दिन्छ']
# Phonetic Code: PKT -> Romanized: ['pachadi'], Root: ['पछाडि']
# Phonetic Code: AJ -> Romanized: ['ajhhai', 'aajhai'], Root: ['अझै']
# Phonetic Code: STPK -> Romanized: ['sadupayog'], Root: ['सदुपयोग']
# Phonetic Code: XH -> Romanized: ['chahi', 'chahe'], Root: ['चाही']
# Phonetic Code: FX -> Romanized: ['vayecha'], Root: ['भएछ']
# Phonetic Code: PTKS -> Romanized: ['patauxha'], Root: ['पठाउछ']
# Phonetic Code: JKR -> Romanized: ['jhukyera', 'jhukera'], Root: ['झुकेर']
# Phonetic Code: T -> Romanized: ['deyo', 'dagh', 'diyo'], Root: ['दियो', 'दाग']
# Phonetic Code: SM -> Romanized: ['samaya', 'samye'], Root: ['समय']
# Phonetic Code: HTN -> Romanized: ['hudaina', 'hudeina'], Root: ['हुदैन']
# Phonetic Code: P0KS -> Romanized: ['pathauxa', 'pathayexa', 'pathauxu'], Root: ['पठाएछ', 'पठाउछ', 'पठाउछु']
# Phonetic Code: HL -> Romanized: ['hola', 'holaa'], Root: ['होला']
# Phonetic Code: TM -> Romanized: ['damiii', 'daam'], Root: ['दाम', 'दामी']
# Phonetic Code: PNKS -> Romanized: ['banauxa'], Root: ['बनाउछ']
# Phonetic Code: HT -> Romanized: ['hudaie', 'hudai'], Root: ['हुदै']
# Phonetic Code: X -> Romanized: ['chyaaaaa'], Root: ['छ्या']
# Phonetic Code: TN -> Romanized: ['diyena', 'diena'], Root: ['दिएन']
# Phonetic Code: PKST -> Romanized: ['paxadi'], Root: ['पछाडि']
# Phonetic Code: 0 -> Romanized: ['thiyo', 'theo'], Root: ['थियो']
# Phonetic Code: ANSR -> Romanized: ['anusara'], Root: ['अनुशार']
# Phonetic Code: KRXN -> Romanized: ['garchan', 'garchhan'], Root: ['गर्छन']
# Phonetic Code: TK -> Romanized: ['daag', 'dagg'], Root: ['दाग']
# Phonetic Code: AL -> Romanized: ['alii', 'aali'], Root: ['अलि']
# Phonetic Code: KR -> Romanized: ['ghara'], Root: ['घर']
# Phonetic Code: KT -> Romanized: ['chhodyo'], Root: ['छोड्यो']
# Phonetic Code: FNKS -> Romanized: ['vanxu'], Root: ['भन्छु']
# Phonetic Code: PNX -> Romanized: ['banaucha', 'bhanchu'], Root: ['भन्छु', 'बनाउछ']
# Phonetic Code: P0K -> Romanized: ['pathako', 'pathaako', 'pathauchha'], Root: ['पठाको', 'पठाउछ']
# Phonetic Code: PHR -> Romanized: ['pohor'], Root: ['फोहोर']
# Phonetic Code: A -> Romanized: ['aaux', 'aux'], Root: ['आउछ']
# Phonetic Code: KM -> Romanized: ['kaam'], Root: ['काम']
# Phonetic Code: ASK -> Romanized: ['yesko'], Root: ['येस्को']
# Phonetic Code: KN -> Romanized: ['kiney', 'kinay', 'chhain', 'chhaina'], Root: [' छैन', 'छैन', 'किने']
# Phonetic Code: NSKK -> Romanized: ['niskeko'], Root: ['निस्केको']
# Phonetic Code: SR -> Romanized: ['saarai', 'saraii'], Root: ['सारै']
# Phonetic Code: FKS -> Romanized: ['vayexa'], Root: ['भएछ']
# Phonetic Code: ASL -> Romanized: ['yesle', 'yasle'], Root: ['एस्ले']
# Phonetic Code: PX -> Romanized: ['pachi'], Root: ['पछि']
# Phonetic Code: AKTMM -> Romanized: ['ekdammm'], Root: ['एकदम']
# Phonetic Code: FTR -> Romanized: ['vitra'], Root: ['भित्र']
# Phonetic Code: PRK -> Romanized: ['parechha'], Root: ['परेछ']

# %%
# Accuracy Evaluation
total_groups = len(nepali_phonetic_groups)
passed_groups = sum(1 for group in nepali_phonetic_groups.values() if len(group["Root"]) == 1)
failed_groups = total_groups - passed_groups
accuracy = (passed_groups / total_groups) * 100 if total_groups else 0

print(f"\nTotal Groups: {total_groups}")
print(f"Passed Groups (One Unique Devanagari): {passed_groups}")
print(f"Failed Groups (Multiple Devanagari): {failed_groups}")
print(f"Phonetic Accuracy (Double Metaphone): {accuracy:.2f}%")
# Out:
# Total Groups: 120
# Passed Groups (One Unique Devanagari): 78
# Failed Groups (Multiple Devanagari): 42
# Phonetic Accuracy (Double Metaphone): 65.00%

# %%
import pandas as pd

data = []
for phonetic_code, groups in nepali_phonetic_groups.items():
    romanized_list = list(groups["Words"])
    devnagari_list = list(groups["Root"])
    data.append({
        "Phonetic Code": phonetic_code,
        "Romanized": romanized_list,
        "Devanagari": devnagari_list
    })

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv("results/metaphone_phonetic_groups.csv", index=False, encoding="utf-8")
