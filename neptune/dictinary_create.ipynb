# %%
import os
import glob
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

def clean_text(text):
    """Remove punctuation while keeping only Devanagari words and spaces."""
    text = re.sub(r'[^\u0900-\u097F\s]', '', text)  # Keep only Devanagari characters and spaces
    text = re.sub(r'[।॥]', '', text)  # Remove Devanagari punctuation marks
    return text


def custom_tokenizer(text):
    """Tokenize text into words while preserving full words."""
    return text.split()  # Simple space-based splitting to keep full words intact

def build_word_count_dictionary(folder_path):
    documents = []
    file_names = glob.glob(os.path.join(folder_path, "*.txt"))[:20]  # Limit to first 20 files

    for file_path in file_names:
        with open(file_path, "r", encoding="utf-8") as f:
            text = f.read()
            cleaned_text = clean_text(text)  # Remove punctuation before tokenization
            documents.append(cleaned_text)

    if not documents:
        return {}

    vectorizer = CountVectorizer(analyzer='word', tokenizer=custom_tokenizer)  # Use custom tokenizer
    word_count_matrix = vectorizer.fit_transform(documents)

    word_counts = np.asarray(word_count_matrix.sum(axis=0)).flatten()
    word_freq_dict = dict(zip(vectorizer.get_feature_names_out(), word_counts))
    # print('word_freq_dict', word_freq_dict)

    sorted_word_freq = dict(sorted(word_freq_dict.items(), key=lambda item: item[1], reverse=True))
    # print('sorted_word_freq', sorted_word_freq)

    # print("Word count dictionary generated for first 20 files (excluding punctuation and preserving full words).")

    return sorted_word_freq



CORPUS_FOLDER = "/Users/chandra/Documents/4th sem/sentiment_analysis/archive/train/train"
WORD_COUNT_DICTIONARY = build_word_count_dictionary(CORPUS_FOLDER)
WORD_COUNT_DICTIONARY
# Out:
# /Users/chandra/Documents/4th sem/sentiment_analysis/venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# {'र': np.int64(49),
#  'थियो': np.int64(22),
#  'हो': np.int64(22),
#  'पनि': np.int64(20),
#  'यो': np.int64(17),
#  'भएको': np.int64(15),
#  'एक': np.int64(14),
#  'छन्': np.int64(13),
#  'तथा': np.int64(13),
#  'थिए': np.int64(13),
#  'छ': np.int64(11),
#  'रूपमा': np.int64(11),
#  'नै': np.int64(10),
#  'द्वारा': np.int64(9),
#  'मा': np.int64(9),
#  'लागि': np.int64(9),
#  'हात्ती': np.int64(9),
#  'उनका': np.int64(8),
#  'पाश्चात्य': np.int64(8),
#  'प्रधानमन्त्री': np.int64(8),
#  'राणा': np.int64(8),
#  'विसं': np.int64(8),
#  'सबैभन्दा': np.int64(8),
#  'उनको': np.int64(7),
#  'उनले': np.int64(7),
#  'उनी': np.int64(7),
#  'नेपालमा': np.int64(7),
#  'शिक्षाको': np.int64(7),
#  'सन्': np.int64(7),
#  'हुन्': np.int64(7),
#  'आफ्नो': np.int64(6),
#  'गोल': np.int64(6),
#  'पहिलो': np.int64(6),
#  'रहेको': np.int64(6),
#  'हात्तीहरू': np.int64(6),
#  'हुन्छ': np.int64(6),
#  'होइन': np.int64(6),
#  'अधिकार': np.int64(5),
#  'ऐन': np.int64(5),
#  'गरे': np.int64(5),
#  'जंगबहादुर': np.int64(5),
#  'ठूलो': np.int64(5),
#  'दुई': np.int64(5),
#  'नेपाल': np.int64(5),
#  'नेपालका': np.int64(5),
#  'नेपालको': np.int64(5),
#  'नेपाली': np.int64(5),
#  'पाइने': np.int64(5),
#  'भए': np.int64(5),
#  'भन्दा': np.int64(5),
#  'यस': np.int64(5),
#  'अन्य': np.int64(4),
#  'अफ्रिकन': np.int64(4),
#  'अवधि': np.int64(4),
#  'इम्जा': np.int64(4),
#  'उक्त': np.int64(4),
#  'एउटा': np.int64(4),
#  'कुनै': np.int64(4),
#  'गरी': np.int64(4),
#  'गर्न': np.int64(4),
#  'चलचित्र': np.int64(4),
#  'जंगबहादुरले': np.int64(4),
#  'जग': np.int64(4),
#  'जङ्गबहादुर': np.int64(4),
#  'त्यस्तै': np.int64(4),
#  'दिन': np.int64(4),
#  'पानी': np.int64(4),
#  'मात्र': np.int64(4),
#  'माध्यमिक': np.int64(4),
#  'मुख्य': np.int64(4),
#  'मुलुकी': np.int64(4),
#  'यसको': np.int64(4),
#  'यसमा': np.int64(4),
#  'रहेका': np.int64(4),
#  'लेख': np.int64(4),
#  'शिक्षा': np.int64(4),
#  'शैक्षिक': np.int64(4),
#  'सबै': np.int64(4),
#  'हिमताल': np.int64(4),
#  'हुन्छन्': np.int64(4),
#  'अनुसार': np.int64(3),
#  'अवस्थामा': np.int64(3),
#  'अस्तित्वमा': np.int64(3),
#  'आदि': np.int64(3),
#  'आदेश': np.int64(3),
#  'उनलाई': np.int64(3),
#  'एवं': np.int64(3),
#  'गते': np.int64(3),
#  'गरिएको': np.int64(3),
#  'गरियो': np.int64(3),
#  'गरेको': np.int64(3),
#  'गर्दा': np.int64(3),
#  'गल्ती': np.int64(3),
#  'ग्रह': np.int64(3),
#  'जिल्लामा': np.int64(3),
#  'त': np.int64(3),
#  'तर': np.int64(3),
#  'तीन': np.int64(3),
#  'त्यही': np.int64(3),
#  'देखि': np.int64(3),
#  'धृतराष्ट्रको': np.int64(3),
#  'धेरै': np.int64(3),
#  'नाम': np.int64(3),
#  'परेको': np.int64(3),
#  'पूर्व': np.int64(3),
#  'प्रथम': np.int64(3),
#  'फर्के': np.int64(3),
#  'बहादुर': np.int64(3),
#  'भने': np.int64(3),
#  'भन्ने': np.int64(3),
#  'भयो': np.int64(3),
#  'भीमसेन': np.int64(3),
#  'मध्ये': np.int64(3),
#  'महाराज': np.int64(3),
#  'यस्तो': np.int64(3),
#  'युद्ध': np.int64(3),
#  'युवराज': np.int64(3),
#  'रानी': np.int64(3),
#  'लिएर': np.int64(3),
#  'वर्णन': np.int64(3),
#  'वर्ष': np.int64(3),
#  'वा': np.int64(3),
#  'विदेशमन्त्री': np.int64(3),
#  'विद्यालय': np.int64(3),
#  'विवाह': np.int64(3),
#  'श्री': np.int64(3),
#  'सामान्यतया': np.int64(3),
#  'सिंह': np.int64(3),
#  'हात्तीको': np.int64(3),
#  'हिम': np.int64(3),
#  'हुने': np.int64(3),
#  'अग्रपंक्ति': np.int64(2),
#  'अङ्ग्रेजी': np.int64(2),
#  'अवधिमा': np.int64(2),
#  'आक्रमक': np.int64(2),
#  'आधुनिक': np.int64(2),
#  'उच्च': np.int64(2),
#  'उद्योग': np.int64(2),
#  'उपेक्षित': np.int64(2),
#  'उसको': np.int64(2),
#  'एशियन': np.int64(2),
#  'कट्टर': np.int64(2),
#  'का': np.int64(2),
#  'कानुन': np.int64(2),
#  'काम': np.int64(2),
#  'कारण': np.int64(2),
#  'कार्य': np.int64(2),
#  'कास्की': np.int64(2),
#  'किस': np.int64(2),
#  'कुँवर': np.int64(2),
#  'कोतको': np.int64(2),
#  'कौरवहरूको': np.int64(2),
#  'क्रमशः': np.int64(2),
#  'क्षेत्रमा': np.int64(2),
#  'क्षेत्रहरूमा': np.int64(2),
#  'खेलाडी': np.int64(2),
#  'गए': np.int64(2),
#  'गरिन्': np.int64(2),
#  'गरेपछि': np.int64(2),
#  'गर्नु': np.int64(2),
#  'गर्ने': np.int64(2),
#  'गायक': np.int64(2),
#  'गृहमन्त्री': np.int64(2),
#  'गोन': np.int64(2),
#  'चिनिन्छ': np.int64(2),
#  'छोराहरूमा': np.int64(2),
#  'छोराहरूले': np.int64(2),
#  'जंग': np.int64(2),
#  'जंगबहादुरको': np.int64(2),
#  'जति': np.int64(2),
#  'जना': np.int64(2),
#  'जनावर': np.int64(2),
#  'जनावरहरू': np.int64(2),
#  'जन्म': np.int64(2),
#  'जमीनमा': np.int64(2),
#  'जम्मा': np.int64(2),
#  'जस्तै': np.int64(2),
#  'जानु': np.int64(2),
#  'जाने': np.int64(2),
#  'जीवन': np.int64(2),
#  'जुन': np.int64(2),
#  'जो': np.int64(2),
#  'तरिकाले': np.int64(2),
#  'तालको': np.int64(2),
#  'तिब्बत': np.int64(2),
#  'तेश्रो': np.int64(2),
#  'तौल': np.int64(2),
#  'त्यसपछि': np.int64(2),
#  'त्यहाँको': np.int64(2),
#  'थापाको': np.int64(2),
#  'थापाथली': np.int64(2),
#  'दरबार': np.int64(2),
#  'दरबारमा': np.int64(2),
#  'देश': np.int64(2),
#  'धामकाे': np.int64(2),
#  'धृतराष्ट्रलाई': np.int64(2),
#  'नयाँ': np.int64(2),
#  'पछि': np.int64(2),
#  'पढ्ने': np.int64(2),
#  'पत्ता': np.int64(2),
#  'पत्रिकाको': np.int64(2),
#  'परामर्श': np.int64(2),
#  'परिवारको': np.int64(2),
#  'परिसरमा': np.int64(2),
#  'पर्छ': np.int64(2),
#  'पर्ने': np.int64(2),
#  'पर्व': np.int64(2),
#  'पश्चात': np.int64(2),
#  'पाइएको': np.int64(2),
#  'पाण्डवहरूको': np.int64(2),
#  'पारेको': np.int64(2),
#  'प्रजातिहरू': np.int64(2),
#  'प्रादुर्भाव': np.int64(2),
#  'बने': np.int64(2),
#  'बस्नेत': np.int64(2),
#  'बाहेक': np.int64(2),
#  'बुद्धि': np.int64(2),
#  'बेलायत': np.int64(2),
#  'बैंग': np.int64(2),
#  'बैठकमा': np.int64(2),
#  'भएका': np.int64(2),
#  'भएर': np.int64(2),
#  'भनिन्छ': np.int64(2),
#  'भाइ': np.int64(2),
#  'मध्य': np.int64(2),
#  'मानव': np.int64(2),
#  'मानिन्छ': np.int64(2),
#  'मिटर': np.int64(2),
#  'यहाँ': np.int64(2),
#  'यिनको': np.int64(2),
#  'यिनीहरू': np.int64(2),
#  'यिनीहरूलाई': np.int64(2),
#  'यी': np.int64(2),
#  'यीनीहरू': np.int64(2),
#  'रहृयो': np.int64(2),
#  'राजा': np.int64(2),
#  'राज्य': np.int64(2),
#  'राणाजी': np.int64(2),
#  'राति': np.int64(2),
#  'राम्रो': np.int64(2),
#  'राष्ट्रिय': np.int64(2),
#  'रुचि': np.int64(2),
#  'लगाउन': np.int64(2),
#  'लोप': np.int64(2),
#  'वर्तमान': np.int64(2),
#  'वातावरण': np.int64(2),
#  'वार्तालाप': np.int64(2),
#  'विक्रम': np.int64(2),
#  'विशाल': np.int64(2),
#  'विश्व': np.int64(2),
#  'शक्ति': np.int64(2),
#  'शक्तिशाली': np.int64(2),
#  'शासन': np.int64(2),
#  'श्रीकृष्ण': np.int64(2),
#  'संजय': np.int64(2),
#  'सकेको': np.int64(2),
#  'सन्देश': np.int64(2),
#  'सन्देशकथन': np.int64(2),
#  'सफल': np.int64(2),
#  'सभामा': np.int64(2),
#  'समेत': np.int64(2),
#  'सम्मान': np.int64(2),
#  'सलामी': np.int64(2),
#  'साना': np.int64(2),
#  'साल': np.int64(2),
#  'सोच': np.int64(2),
#  'स्कोरिङ्गको': np.int64(2),
#  'स्ट्राइकर': np.int64(2),
#  'स्थापना': np.int64(2),
#  'हत्यारा': np.int64(2),
#  'हस्तान्तरण': np.int64(2),
#  'हात्तीका': np.int64(2),
#  'हात्तीहरूको': np.int64(2),
#  'हात्तीहरूलाई': np.int64(2),
#  'हाल': np.int64(2),
#  'हुँदा': np.int64(2),
#  'हुँदै': np.int64(2),
#  'हुन': np.int64(2),
#  'हुनु': np.int64(2),
#  'अंगोलामा': np.int64(1),
#  'अंग्रेजसँग': np.int64(1),
#  'अक्षमा': np.int64(1),
#  'अक्सर': np.int64(1),
#  'अख्तर': np.int64(1),
#  'अगष्ट': np.int64(1),
#  'अग्रस्थान': np.int64(1),
#  'अग्रस्थानमा': np.int64(1),
#  'अग्लो': np.int64(1),
#  'अङरक्षक': np.int64(1),
#  'अङ्ग्रेजलाई': np.int64(1),
#  'अङ्ग्रेजसंगको': np.int64(1),
#  'अदम्य': np.int64(1),
#  'अधिक': np.int64(1),
#  'अधिकारीद्वारा': np.int64(1),
#  'अध्ययनरत': np.int64(1),
#  'अध्ययनले': np.int64(1),
#  'अध्ययनहरू': np.int64(1),
#  'अध्ययनहरूले': np.int64(1),
#  'अध्याय': np.int64(1),
#  'अनन्त': np.int64(1),
#  'अनर': np.int64(1),
#  'अनुवाद': np.int64(1),
#  'अनुवादक': np.int64(1),
#  'अन्ततः': np.int64(1),
#  'अन्तर्गत': np.int64(1),
#  'अन्तिम': np.int64(1),
#  'अन्त्य': np.int64(1),
#  'अन्त्यसगै': np.int64(1),
#  'अपमान': np.int64(1),
#  'अपराध': np.int64(1),
#  'अप्राप्य': np.int64(1),
#  'अफ': np.int64(1),
#  'अब': np.int64(1),
#  'अभिनत्री': np.int64(1),
#  'अभिनयको': np.int64(1),
#  'अभिनित': np.int64(1),
#  'अभिमान': np.int64(1),
#  'अभिमानका': np.int64(1),
#  'अभिलेख': np.int64(1),
#  'अमिताभ': np.int64(1),
#  'अमेरिका': np.int64(1),
#  'अमेरिकाका': np.int64(1),
#  'अमेरिकाको': np.int64(1),
#  'अमेरिकामा': np.int64(1),
#  'अमेरिकी': np.int64(1),
#  'अम्बोपाख्यान': np.int64(1),
#  'अरु': np.int64(1),
#  'अरुणग्रह': np.int64(1),
#  'अर्कामा': np.int64(1),
#  'अर्को': np.int64(1),
#  'अर्थविद्': np.int64(1),
#  'अलब्राइट': np.int64(1),
#  'अलावा': np.int64(1),
#  'अवैध': np.int64(1),
#  'असार': np.int64(1),
#  'असोज': np.int64(1),
#  'अहितकारी': np.int64(1),
#  'अहिले': np.int64(1),
#  'अहिलेसम्म': np.int64(1),
#  'अहिलेसम्मको': np.int64(1),
#  'अाध्यात्मिक': np.int64(1),
#  'आई': np.int64(1),
#  'आएर': np.int64(1),
#  'आकारको': np.int64(1),
#  'आचार्य': np.int64(1),
#  'आततायी': np.int64(1),
#  'आदेशले': np.int64(1),
#  'आना': np.int64(1),
#  'आन्तरिक': np.int64(1),
#  'आफूभित्रको': np.int64(1),
#  'आफ्ना': np.int64(1),
#  'आयरल्याण्डमा': np.int64(1),
#  'आयू': np.int64(1),
#  'आयोवा': np.int64(1),
#  'आर्यन': np.int64(1),
#  'आवश्यकता': np.int64(1),
#  'इतिहासमा': np.int64(1),
#  'इनारमा': np.int64(1),
#  'इम्पसिबल': np.int64(1),
#  'इसा': np.int64(1),
#  'ई': np.int64(1),
#  'ईगल': np.int64(1),
#  'ईमा': np.int64(1),
#  'उचाइ': np.int64(1),
#  'उठाएर': np.int64(1),
#  'उता': np.int64(1),
#  'उद्दरण': np.int64(1),
#  'उनकै': np.int64(1),
#  'उनीबाटै': np.int64(1),
#  'उनीमाथि': np.int64(1),
#  'उपग्रहहरू': np.int64(1),
#  'उपदेश': np.int64(1),
#  'उपनिषद्का': np.int64(1),
#  'उपपर्व': np.int64(1),
#  'उपरोक्त': np.int64(1),
#  'उपाधि': np.int64(1),
#  'उलूक': np.int64(1),
#  'उल्लेख्य': np.int64(1),
#  'एकएक': np.int64(1),
#  'एकतन्त्री': np.int64(1),
#  'एकत्र': np.int64(1),
#  'एकप्रकारको': np.int64(1),
#  'एसियाकै': np.int64(1),
#  'एसियाली': np.int64(1),
#  'ओलीको': np.int64(1),
#  'औद्योगिक': np.int64(1),
#  'औपचारिक': np.int64(1),
#  'औशत': np.int64(1),
#  'कञ्चनपुर': np.int64(1),
#  'कथानक': np.int64(1),
#  'कम': np.int64(1),
#  'कमजोर': np.int64(1),
#  'करिब': np.int64(1),
#  'करोड': np.int64(1),
#  'कर्णेल': np.int64(1),
#  'कलकत्ताबाट': np.int64(1),
#  'कलको': np.int64(1),
#  'कला': np.int64(1),
#  'कलेज': np.int64(1),
#  'कलेजमा': np.int64(1),
#  'कहिन्थ्यो': np.int64(1),
#  'काजीका': np.int64(1),
#  'काठमाडौँमा': np.int64(1),
#  'काठमाडौं': np.int64(1),
#  'काठमाडौंको': np.int64(1),
#  'कानुनमा': np.int64(1),
#  'कारक': np.int64(1),
#  'कार्यका': np.int64(1),
#  'कार्यमा': np.int64(1),
#  'काली': np.int64(1),
#  'काव्य': np.int64(1),
#  'कि': np.int64(1),
#  'किड': np.int64(1),
#  'किनीक': np.int64(1),
#  'किरदारमा': np.int64(1),
#  'किलोग्राम': np.int64(1),
#  'कुँवरका': np.int64(1),
#  'कुण्ठित': np.int64(1),
#  'कुद्ने': np.int64(1),
#  'कुमार': np.int64(1),
#  'कुमारीको': np.int64(1),
#  'कुरा': np.int64(1),
#  'कुल': np.int64(1),
#  'कृषि': np.int64(1),
#  'कृष्ण': np.int64(1),
#  'के': np.int64(1),
#  'केपी': np.int64(1),
#  'केहीको': np.int64(1),
#  'कैलशानन्द': np.int64(1),
#  'कैलाली': np.int64(1),
#  'कैलाशानन्दकाे': np.int64(1),
#  'कैलाशानन्दको': np.int64(1),
#  'कोडमा': np.int64(1),
#  'कोतपर्वको': np.int64(1),
#  'कोतबाट': np.int64(1),
#  'कोतभित्र': np.int64(1),
#  'कोतमा': np.int64(1),
#  'कोलम्बिया': np.int64(1),
#  'कौरवहरू': np.int64(1),
#  'कौरवहरूका': np.int64(1),
#  'कौरवहरूलाई': np.int64(1),
#  'क्यानिंगले': np.int64(1),
#  'क्याम्पस': np.int64(1),
#  'क्रममा': np.int64(1),
#  'क्रमैले': np.int64(1),
#  'क्रान्तिकारी': np.int64(1),
#  'क्रेट': np.int64(1),
#  'क्लिक': np.int64(1),
#  'क्लिन्टनले': np.int64(1),
#  'क्षेत्रको': np.int64(1),
#  'खतरनाक': np.int64(1),
#  'खलनायकका': np.int64(1),
#  'खुसी': np.int64(1),
#  'खेलमा': np.int64(1),
#  'खेलाडिहरू': np.int64(1),
#  'खेलाडिहरूले': np.int64(1),
#  'खेलाडीहरूलाई': np.int64(1),
#  'खेलेर': np.int64(1),
#  'खेल्ने': np.int64(1),
#  'खोला': np.int64(1),
#  'खोसियो': np.int64(1),
#  'गगन': np.int64(1),
#  'गगनसिंहको': np.int64(1),
#  'गजराज': np.int64(1),
#  'गणेश': np.int64(1),
#  'गति': np.int64(1),
#  'गतेका': np.int64(1),
#  'गयापतालक': np.int64(1),
#  'गयो': np.int64(1),
#  'गरिन्छयतिञ्जेल': np.int64(1),
#  'गरुडगालवसंवाद': np.int64(1),
#  'गरेका': np.int64(1),
#  'गरेर': np.int64(1),
#  'गर्छन्': np.int64(1),
#  'गर्छिन्': np.int64(1),
#  'गर्नको': np.int64(1),
#  'गर्नुका': np.int64(1),
#  'गर्नेमा': np.int64(1),
#  'गर्भधारण': np.int64(1),
#  'गर्यो': np.int64(1),
#  'गहिराइ': np.int64(1),
#  'गारिएको': np.int64(1),
#  'गीतहरू': np.int64(1),
#  'गुमेको': np.int64(1),
#  'गोपाल': np.int64(1),
#  'गोलपोष्ट': np.int64(1),
#  'गोलबैठक': np.int64(1),
#  'गोलबैठकमा': np.int64(1),
#  'गोली': np.int64(1),
#  'गौरब': np.int64(1),
#  'ग्याँस': np.int64(1),
#  'घन': np.int64(1),
#  'घुसपैठ': np.int64(1),
#  'घोडा': np.int64(1),
#  'घोषणा': np.int64(1),
#  'घोषणापत्रमा': np.int64(1),
#  'घोषित': np.int64(1),
#  'चञ्चले': np.int64(1),
#  'चतरा': np.int64(1),
#  'चतुर': np.int64(1),
#  'चयन': np.int64(1),
#  'चरित्रका': np.int64(1),
#  'चर्किदै': np.int64(1),
#  'चर्चित': np.int64(1),
#  'चलन': np.int64(1),
#  'चलाए': np.int64(1),
#  'चातुर्यका': np.int64(1),
#  'चाहन्थे': np.int64(1),
#  'चाहिं': np.int64(1),
#  'चितवन': np.int64(1),
#  'चिन': np.int64(1),
#  'चिनियाँ': np.int64(1),
#  'चिरस्थायी': np.int64(1),
#  'चीसो': np.int64(1),
#  'चेक': np.int64(1),
#  'चेकोस्लोभाकिया': np.int64(1),
#  'चोटमा': np.int64(1),
#  'चोपड़ा': np.int64(1),
#  'छँदै': np.int64(1),
#  'छावा': np.int64(1),
#  'छावाहरू': np.int64(1),
#  'छिटो': np.int64(1),
#  'छिमेकी': np.int64(1),
#  'छुट': np.int64(1),
#  'छैनन्': np.int64(1),
#  'छोरा': np.int64(1),
#  'छोराका': np.int64(1),
#  'छोराहरू': np.int64(1),
#  'छोराहरूलाई': np.int64(1),
#  'छोरी': np.int64(1),
#  'छोरीहरू': np.int64(1),
#  'छोरीहरूको': np.int64(1),
#  'छ्न्': np.int64(1),
#  'जंगबहादुरका': np.int64(1),
#  'जंगबहादुरकै': np.int64(1),
#  'जङ्ग': np.int64(1),
#  'जङ्गबहादुरका': np.int64(1),
#  'जङ्गबहादुरलाई': np.int64(1),
#  'जङ्गबहादुरले': np.int64(1),
#  'जङ्गलमा': np.int64(1),
#  'जनजीवन': np.int64(1),
#  'जनाको': np.int64(1),
#  'जनावरको': np.int64(1),
#  'जनिने': np.int64(1),
#  'जन्मदा': np.int64(1),
#  'जन्मदाकै': np.int64(1),
#  'जब': np.int64(1),
#  'जसअनुसार': np.int64(1),
#  'जसको': np.int64(1),
#  'जसले': np.int64(1),
#  'जस्ता': np.int64(1),
#  'जागरण': np.int64(1),
#  'जागिर': np.int64(1),
#  'जाना': np.int64(1),
#  'जारि': np.int64(1),
#  'जित्न': np.int64(1),
#  'जिम्मेवार': np.int64(1),
#  'जिम्मेवारीले': np.int64(1),
#  'जिल्ला': np.int64(1),
#  'जिल्लाहरूको': np.int64(1),
#  'जीर्ण': np.int64(1),
#  'जुध्ने': np.int64(1),
#  'जुनकालमा': np.int64(1),
#  'जुनलाई': np.int64(1),
#  'जुवाडे': np.int64(1),
#  'जेठमा': np.int64(1),
#  'जेठी': np.int64(1),
#  'जोखम': np.int64(1),
#  'जोखिमयुक्त': np.int64(1),
#  'जोन': np.int64(1),
#  'जोरजुलुम': np.int64(1),
#  'ज्ञाता': np.int64(1),
#  'ज्ञानको': np.int64(1),
#  'ज्ञानरत्न': np.int64(1),
#  'ज्यादा': np.int64(1),
#  'ज्यादै': np.int64(1),
#  'झन्': np.int64(1),
#  'झाडीमा': np.int64(1),
#  'टांडी': np.int64(1),
#  'टाक्सिन': np.int64(1),
#  'टीम': np.int64(1),
#  'टीमहरूका': np.int64(1),
#  'ठीक': np.int64(1),
#  'ठूला': np.int64(1),
#  'डल्फिन': np.int64(1),
#  'ढंगले': np.int64(1),
#  'ढङ्गले': np.int64(1),
#  'ढर्राको': np.int64(1),
#  'ढल्केको': np.int64(1),
#  'तनावको': np.int64(1),
#  'तराई': np.int64(1),
#  'तल्लीन': np.int64(1),
#  'तानाशाह': np.int64(1),
#  'तानासाह': np.int64(1),
#  'तिर': np.int64(1),
#  'ती': np.int64(1),
#  'तीनताका': np.int64(1),
#  'तेर्सो': np.int64(1),
#  'तैयारी': np.int64(1),
#  'तोपको': np.int64(1),
#  'त्यतिखेर': np.int64(1),
#  'त्यत्तिकै': np.int64(1),
#  'त्यसबाहेक': np.int64(1),
#  'त्यसरी': np.int64(1),
#  'त्यसैगरी': np.int64(1),
#  'त्यसैले': np.int64(1),
#  'त्यस्तो': np.int64(1),
#  'त्यो': np.int64(1),
#  'त्रिभुवन': np.int64(1),
#  'त्रिसुलि': np.int64(1),
#  'त्रुटिहरु': np.int64(1),
#  'त्रुटी': np.int64(1),
#  'त्रैलोक्य': np.int64(1),
#  'थापा': np.int64(1),
#  'थापाथलीमा': np.int64(1),
#  'थापाले': np.int64(1),
#  'थापासँग': np.int64(1),
#  'थाले': np.int64(1),
#  'थालेपछि': np.int64(1),
#  'थिएन': np.int64(1),
#  'द': np.int64(1),
#  'दण्ड': np.int64(1),
#  'दरबारिया': np.int64(1),
#  'दरवार': np.int64(1),
#  'दलबलका': np.int64(1),
#  'दलभञ्जन': np.int64(1),
#  'दिइयो': np.int64(1),
#  'दिएर': np.int64(1),
#  'दिनमा': np.int64(1),
#  'दिने': np.int64(1),
#  'दुइटै': np.int64(1),
#  'दुखलाग्दो': np.int64(1),
#  'दुर्भाग्य': np.int64(1),
#  'दुर्योधन': np.int64(1),
#  'दुर्योधनका': np.int64(1),
#  'दुर्योधनलाई': np.int64(1),
#  'दूत': np.int64(1),
#  'दृष्टिले': np.int64(1),
#  'दृष्टीकोणले': np.int64(1),
#  'देखिने': np.int64(1),
#  'देखेका': np.int64(1),
#  'देवीको': np.int64(1),
#  'देशको': np.int64(1),
#  'दोस्रो': np.int64(1),
#  'द्धिपमा': np.int64(1),
#  'द्रूपदका': np.int64(1),
#  'द्रूपदको': np.int64(1),
#  'द्वितीय': np.int64(1),
#  'धन्टाैसम्म': np.int64(1),
#  'धरहराबाट': np.int64(1),
#  'धाराप्रवाह': np.int64(1),
#  'धार्मिक': np.int64(1),
#  'धीरेन्द्र': np.int64(1),
#  'धृतराष्ट्र': np.int64(1),
#  'ध्रुवीय': np.int64(1),
#  'न': np.int64(1),
#  'नगरपालिका': np.int64(1),
#  'नजीक': np.int64(1),
#  'नदिमा': np.int64(1),
#  'नरसंहार': np.int64(1),
#  'नरेन्द्रसँग': np.int64(1),
#  'नागालैंडका': np.int64(1),
#  'नानी': np.int64(1),
#  'नामले': np.int64(1),
#  'नाम्बियार': np.int64(1),
#  'निकालेनेपालमा': np.int64(1),
#  'निकालेर': np.int64(1),
#  'निकै': np.int64(1),
#  'निग्रह': np.int64(1),
#  'निम्न': np.int64(1),
#  'नियुक्त': np.int64(1),
#  'निरङ्कुश': np.int64(1),
#  'निरीक्षण': np.int64(1),
#  'निर्देशक': np.int64(1),
#  'निर्माण': np.int64(1),
#  'निर्माता': np.int64(1),
#  'निवास': np.int64(1),
#  'निश्चय': np.int64(1),
#  'निष्कर्ष': np.int64(1),
#  'निष्पादन': np.int64(1),
#  'निस्केका': np.int64(1),
#  'निहुरिने': np.int64(1),
#  'नीति': np.int64(1),
#  'नेपालकै': np.int64(1),
#  'नेपालबाट': np.int64(1),
#  'नेपालले': np.int64(1),
#  'नेपालीको': np.int64(1),
#  'पक्षदेखि': np.int64(1),
#  'पक्षहरूको': np.int64(1),
#  'पग्लिएको': np.int64(1),
#  'पछाडि': np.int64(1),
#  'पछिबाट': np.int64(1),
#  'पटक': np.int64(1),
#  'पटनाको': np.int64(1),
#  'पठनपाठन': np.int64(1),
#  'पठाउनु': np.int64(1),
#  'पढाइ': np.int64(1),
#  'पढिन': np.int64(1),
#  'पतन': np.int64(1),
#  'पत्थरघट्टामा': np.int64(1),
#  'पत्रिका': np.int64(1),
#  'पदमा': np.int64(1),
#  'परख': np.int64(1),
#  'परिवार': np.int64(1),
#  'परिवारमा': np.int64(1),
#  'पर्थ्यो': np.int64(1),
#  'पर्न': np.int64(1),
#  'पर्यो': np.int64(1),
#  'पर्वका': np.int64(1),
#  'पर्वमा': np.int64(1),
#  'पश्चिमतर्फ': np.int64(1),
#  'पश्चिममा': np.int64(1),
#  'पश्चिमी': np.int64(1),
#  'पाँडे': np.int64(1),
#  'पाउँदै': np.int64(1),
#  'पाउन्ड': np.int64(1),
#  'पाण्डव': np.int64(1),
#  'पाण्डवसभामा': np.int64(1),
#  'पाण्डवहरू': np.int64(1),
#  'पाण्डवहरूका': np.int64(1),
#  'पाण्डवहरूसित': np.int64(1),
#  'पात्र': np.int64(1),
#  'पायो': np.int64(1),
#  'पारिवरिक': np.int64(1),
#  'पारी': np.int64(1),
#  'पार्टीमा': np.int64(1),
#  'पार्न': np.int64(1),
#  'पालना': np.int64(1),
#  'पालमा': np.int64(1),
#  'पालामा': np.int64(1),
#  'पिटर': np.int64(1),
#  'पिण्ड': np.int64(1),
#  'पीठाधीशका': np.int64(1),
#  'पुगे': np.int64(1),
#  'पुगेका': np.int64(1),
#  'पुन': np.int64(1),
#  'पुनर्जन्म': np.int64(1),
#  'पुरोहित': np.int64(1),
#  'पुर्याउँने': np.int64(1),
#  'पुष्टी': np.int64(1),
#  'पूर्ण': np.int64(1),
#  'पूर्वमा': np.int64(1),
#  'पृथक': np.int64(1),
#  'पृथ्वीबाट': np.int64(1),
#  'पैदा': np.int64(1),
#  'पोखरीको': np.int64(1),
#  'पोखरीमा': np.int64(1),
#  'प्रकारका': np.int64(1),
#  'प्रकारको': np.int64(1),
#  'प्रकाशक': np.int64(1),
#  'प्रकाशन': np.int64(1),
#  'प्रकाशित': np.int64(1),
#  'प्रख्यात': np.int64(1),
#  'प्रगति': np.int64(1),
#  'प्रगतिको': np.int64(1),
#  'प्रजाति': np.int64(1),
#  'प्रति': np.int64(1),
#  'प्रतिष्ठापित': np.int64(1),
#  'प्रतीक': np.int64(1),
#  'प्रदर्शन': np.int64(1),
#  'प्रदान': np.int64(1),
#  'प्रधानमन्त्रीका': np.int64(1),
#  'प्रध्यानाध्यापक': np.int64(1),
#  'प्रभाव': np.int64(1),
#  'प्रयोग': np.int64(1),
#  'प्रवचन': np.int64(1),
#  'प्रवचनले': np.int64(1),
#  'प्रशन्न': np.int64(1),
#  'प्रशिक्षकले': np.int64(1),
#  'प्रसङ्ग': np.int64(1),
#  'प्रसिद्द': np.int64(1),
#  'प्रसिद्ध': np.int64(1),
#  'प्रस्ताव': np.int64(1),
#  'प्राकृतिक': np.int64(1),
#  'प्रागऐतिहासिक': np.int64(1),
#  'प्रागैतिहासिक': np.int64(1),
#  'प्राचिनकालमा': np.int64(1),
#  'प्रारम्भमा': np.int64(1),
#  'प्रिय': np.int64(1),
#  'फत्तेजङ्ग': np.int64(1),
#  'फरहान': np.int64(1),
#  'फर्काइएको': np.int64(1),
#  'फर्काउन': np.int64(1),
#  'फर्केपछि': np.int64(1),
#  'फाइदा': np.int64(1),
#  'फाल्ने': np.int64(1),
#  'फिल्म': np.int64(1),
#  'फिल्ममा': np.int64(1),
#  'फुटबल': np.int64(1),
#  'फुटबलमा': np.int64(1),
#  'फेर्दैछ': np.int64(1),
#  'फ्रान्सबाट': np.int64(1),
#  'फ्रान्समा': np.int64(1),
#  'बग्यो': np.int64(1),
#  'बचेको': np.int64(1),
#  'बच्चन': np.int64(1),
#  'बझाङी': np.int64(1),
#  'बढिरहेको': np.int64(1),
#  'बताइन्छ': np.int64(1),
#  'बदन': np.int64(1),
#  'बनाइए': np.int64(1),
#  'बनाइन्': np.int64(1),
#  'बनाई': np.int64(1),
#  'बनाउने': np.int64(1),
#  'बनाए': np.int64(1),
#  'बनाएका': np.int64(1),
#  'बनेको': np.int64(1),
#  'बन्दी': np.int64(1),
#  'बन्यो': np.int64(1),
#  'बब': np.int64(1),
#  'बमोजिम': np.int64(1),
#  'बराबर': np.int64(1),
#  'बर्दीया': np.int64(1),
#  'बर्षको': np.int64(1),
#  'बर्षसम्म': np.int64(1),
#  'बर्षे': np.int64(1),
#  'बलराम': np.int64(1),
#  'बलियो': np.int64(1),
#  'बसन्ती': np.int64(1),
#  'बसाले': np.int64(1),
#  'बसालेका': np.int64(1),
#  'बस्दथे': np.int64(1),
#  'बस्यो': np.int64(1),
#  'बहादुरले': np.int64(1),
#  'बाँके': np.int64(1),
#  'बाघ': np.int64(1),
#  'बाच्छा': np.int64(1),
#  'बाट': np.int64(1),
#  'बालनरसिंह': np.int64(1),
#  'बालनरसिंहको': np.int64(1),
#  'बाल्यकाल': np.int64(1),
#  'बाहदुर': np.int64(1),
#  'बाहिर': np.int64(1),
#  'बाह्य': np.int64(1),
#  'बाह्र': np.int64(1),
#  'बिक्रम': np.int64(1),
#  'बिचल्ली': np.int64(1),
#  'बिजय': np.int64(1),
#  'बित्यो': np.int64(1),
#  'बिल': np.int64(1),
#  'बीसीको': np.int64(1),
#  'बुद्धिका': np.int64(1),
#  'बेत्रावती': np.int64(1),
#  'बेबी': np.int64(1),
#  'बेलायतीहरूका': np.int64(1),
#  'बेलायात': np.int64(1),
#  'ब्रिटिशसँग': np.int64(1),
#  'ब्रिटेनमा': np.int64(1),
#  'भइसकेका': np.int64(1),
#  'भइसकेपछी': np.int64(1),
#  'भइहरू': np.int64(1),
#  'भएकाले': np.int64(1),
#  'भएकै': np.int64(1),
#  'भक्त': np.int64(1),
#  'भण्डारखाल': np.int64(1),
#  'भण्डारीको': np.int64(1),
#  'भतिजाहरू': np.int64(1),
#  'भदौ': np.int64(1),
#  'भनाभन': np.int64(1),
#  'भर्ती': np.int64(1),
#  'भवन': np.int64(1),
#  'भव्य': np.int64(1),
#  'भाइहरू': np.int64(1),
#  'भानु': np.int64(1),
#  'भानुभक्त': np.int64(1),
#  'भारतका': np.int64(1),
#  'भारतीय': np.int64(1),
#  'भारदारका': np.int64(1),
#  'भारदारहरूलाई': np.int64(1),
#  'भाले': np.int64(1),
#  'भाषाका': np.int64(1),
#  'भाषाको': np.int64(1),
#  'भाषामा': np.int64(1),
#  'भीष्मपरशुरामको': np.int64(1),
#  'भेट': np.int64(1),
#  'भेटिन्': np.int64(1),
#  'भेला': np.int64(1),
#  'भोग': np.int64(1),
#  'भोट': np.int64(1),
#  'भ्रमण': np.int64(1),
#  'भ्रमणमा': np.int64(1),
#  'मगर': np.int64(1),
#  'मनमा': np.int64(1),
#  'मन्त्रमुग्ध': np.int64(1),
#  'मन्त्रिपरिषद्का': np.int64(1),
#  'मन्त्री': np.int64(1),
#  'मरणासन्न': np.int64(1),
#  'मलमपट्टी': np.int64(1),
#  'महँगा': np.int64(1),
#  'महाकवि': np.int64(1),
#  'महाकाली': np.int64(1),
#  'महारानी': np.int64(1),
#  'महारानीको': np.int64(1),
#  'महिनाको': np.int64(1),
#  'महिला': np.int64(1),
#  'माग': np.int64(1),
#  'माघमा': np.int64(1),
#  'माथवरसिंह': np.int64(1),
#  'मानन्धर': np.int64(1),
#  'मानिस': np.int64(1),
#  'मान्नु': np.int64(1),
#  'मामाघर': np.int64(1),
#  'मारिएको': np.int64(1),
#  'मारिएपछि': np.int64(1),
#  'मारेर': np.int64(1),
#  'मार्च': np.int64(1),
#  'मावली': np.int64(1),
#  'मास्टर': np.int64(1),
#  'मिशन': np.int64(1),
#  'मिशेल': np.int64(1),
#  'मुख्यतः': np.int64(1),
#  'मुजफरपुरमा': np.int64(1),
#  'मुटु': np.int64(1),
#  'मुलाकात': np.int64(1),
#  'मुलुकको': np.int64(1),
#  'मृत्यु': np.int64(1),
#  'मेचीसम्म': np.int64(1),
#  'मेड': np.int64(1),
#  'मेडलिन': np.int64(1),
#  'मेमोरियल': np.int64(1),
#  'मेरो': np.int64(1),
#  'मेलमिलापकै': np.int64(1),
#  'मेलमिलापबाट': np.int64(1),
#  'मैथिली': np.int64(1),
#  'मैले': np.int64(1),
#  'मोडलिङ': np.int64(1),
#  'मोनाघन': np.int64(1),
#  'यथास्थान': np.int64(1),
#  'यसअनुसार': np.int64(1),
#  'यसका': np.int64(1),
#  'यसले': np.int64(1),
#  'यसै': np.int64(1),
#  'यसैले': np.int64(1),
#  'यस्को': np.int64(1),
#  'यस्ता': np.int64(1),
#  'या': np.int64(1),
#  'यात्राबाट': np.int64(1),
#  'यिनले': np.int64(1),
#  'युगका': np.int64(1),
#  'युगको': np.int64(1),
#  'युद्धका': np.int64(1),
#  'युद्धको': np.int64(1),
#  'युद्धवीर': np.int64(1),
#  'युद्धसज्जित': np.int64(1),
#  'युधिष्ठिरका': np.int64(1),
#  'युधिष्ठिरसित': np.int64(1),
#  'योगीका': np.int64(1),
#  'रक्षात्मक': np.int64(1),
#  'रगतको': np.int64(1),
#  'रचित': np.int64(1),
#  'रणोद्विपसिंह': np.int64(1),
#  'रत्ननगर': np.int64(1),
#  'रहदा': np.int64(1),
#  'रहने': np.int64(1),
#  'रहन्छन्': np.int64(1),
#  'रहस्यमय': np.int64(1),
#  'रहिन्': np.int64(1),
#  'रहेछ': np.int64(1),
#  'राख्ने': np.int64(1),
#  'राजकुमार': np.int64(1),
#  'राजधानी': np.int64(1),
#  'राजनीतिक': np.int64(1),
#  'राजप्रतिनिधिमण्डलले': np.int64(1),
#  'राजसंस्था': np.int64(1),
#  'राजाप्रजालाई': np.int64(1),
#  'राजाबाट': np.int64(1),
#  'राज्यलक्ष्मी': np.int64(1),
#  'राणाकाल': np.int64(1),
#  'राणाकालको': np.int64(1),
#  'राणाकालपूर्वका': np.int64(1),
#  'राणाको': np.int64(1),
#  'राणाले': np.int64(1),
#  'राना': np.int64(1),
#  'राप्तीदेखि': np.int64(1),
#  'राष्ट्र': np.int64(1),
#  'राष्ट्रपति': np.int64(1),
#  'रिपब्लिक': np.int64(1),
#  'रूपले': np.int64(1),
#  'रोमका': np.int64(1),
#  'रोमन': np.int64(1),
#  'लगत्तै': np.int64(1),
#  'लगभग': np.int64(1),
#  'लगाउने': np.int64(1),
#  'लगायतका': np.int64(1),
#  'लडाईंमा': np.int64(1),
#  'लडेर': np.int64(1),
#  'लड्ने': np.int64(1),
#  'लफङ्गा': np.int64(1),
#  'लमजुङका': np.int64(1),
#  'लमजुङको': np.int64(1),
#  'लाई': np.int64(1),
#  'लाख': np.int64(1),
#  'लिंदै': np.int64(1),
#  'लिई': np.int64(1),
#  'लिएको': np.int64(1),
#  'लिखित': np.int64(1),
#  'लिटर': np.int64(1),
#  'लिन': np.int64(1),
#  'लिनुपर्छ': np.int64(1),
#  'लिनुपर्ने': np.int64(1),
#  ...}

# %%
import os
import glob
import re
import numpy as np
import pickle
from sklearn.feature_extraction.text import CountVectorizer

PICKLE_FILE = "/Users/chandra/Documents/4th sem/sentiment_analysis/dictionary/word_count.pkl"  # Path to store the frequency dictionary

def clean_text(text):
    """Remove punctuation while keeping only Devanagari words and spaces."""
    text = re.sub(r'[^\u0900-\u097F\s]', '', text)  # Keep only Devanagari characters and spaces
    text = re.sub(r'[।॥]', '', text)  # Remove Devanagari punctuation marks
    return text


def custom_tokenizer(text):
    """Tokenize text into words while preserving full words."""
    return text.split()  # Simple space-based splitting to keep full words intact

def load_existing_data():
    """Load word frequency dictionary from a pickle file if it exists."""
    if os.path.exists(PICKLE_FILE):
        with open(PICKLE_FILE, "rb") as f:
            return pickle.load(f)
    return {}  # Return empty dictionary if no existing data

def save_data(data):
    """Save the updated word frequency dictionary to a pickle file."""
    with open(PICKLE_FILE, "wb") as f:
        pickle.dump(data, f)

def build_word_count_dictionary(folder_path):
    existing_word_count = load_existing_data()  # Load existing data

    documents = []
    file_names = glob.glob(os.path.join(folder_path, "*.txt"))  # Limit to first 20 files

    for file_path in file_names:
        with open(file_path, "r", encoding="utf-8") as f:
            text = f.read()
            cleaned_text = clean_text(text)  # Remove punctuation before tokenization
            documents.append(cleaned_text)

    # if not documents:
    #     return existing_word_count  # Return existing data if no new documents found

    vectorizer = CountVectorizer(analyzer='word', tokenizer=custom_tokenizer)  # Use custom tokenizer
    word_count_matrix = vectorizer.fit_transform(documents)

    word_counts = np.asarray(word_count_matrix.sum(axis=0)).flatten()
    new_word_freq_dict = dict(zip(vectorizer.get_feature_names_out(), word_counts))

    # Merge existing and new word counts
    for word, count in new_word_freq_dict.items():
        existing_word_count[word] = existing_word_count.get(word, 0) + count

    # Sort by frequency (descending order)
    sorted_word_freq = dict(sorted(existing_word_count.items(), key=lambda item: item[1], reverse=True))

    # Save the updated dictionary
    save_data(sorted_word_freq)

    print("Word count dictionary updated and saved.")

    return sorted_word_freq

# Usage
CORPUS_FOLDER = "/Users/chandra/Documents/4th sem/sentiment_analysis/archive/train/train"
WORD_COUNT_DICTIONARY = build_word_count_dictionary(CORPUS_FOLDER)
len(WORD_COUNT_DICTIONARY)
WORD_COUNT_DICTIONARY
# Out:
# /Users/chandra/Documents/4th sem/sentiment_analysis/venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Word count dictionary updated and saved.
# {'र': np.int64(71188),
#  'छ': np.int64(40288),
#  'हो': np.int64(38885),
#  'यो': np.int64(29268),
#  'पनि': np.int64(28314),
#  'एक': np.int64(23869),
#  'थियो': np.int64(19582),
#  'यस': np.int64(18421),
#  'मा': np.int64(17689),
#  'तथा': np.int64(17604),
#  'भएको': np.int64(17383),
#  'थिए': np.int64(14992),
#  'छन्': np.int64(14750),
#  'रहेको': np.int64(13554),
#  'को': np.int64(12720),
#  'लागि': np.int64(12437),
#  'भने': np.int64(11554),
#  'हुन्छ': np.int64(11381),
#  'गर्ने': np.int64(9930),
#  'आफ्नो': np.int64(9446),
#  'रूपमा': np.int64(9303),
#  'गर्न': np.int64(9063),
#  'वा': np.int64(8942),
#  'हुन्': np.int64(8546),
#  'नेपालको': np.int64(8316),
#  'नेपाली': np.int64(7924),
#  'सन्': np.int64(7880),
#  'नै': np.int64(7675),
#  'विकास': np.int64(7671),
#  'गरेको': np.int64(7297),
#  'उनले': np.int64(7209),
#  'यसको': np.int64(6936),
#  'गरिएको': np.int64(6804),
#  'तर': np.int64(6703),
#  'गरेका': np.int64(6584),
#  'नेपाल': np.int64(6422),
#  'उनी': np.int64(6122),
#  'अनुसार': np.int64(5989),
#  'गरे': np.int64(5935),
#  'भन्ने': np.int64(5917),
#  'हुने': np.int64(5894),
#  'देखि': np.int64(5836),
#  'एउटा': np.int64(5660),
#  'धेरै': np.int64(5563),
#  'गरी': np.int64(5500),
#  'उनको': np.int64(5442),
#  'गरिन्छ': np.int64(5269),
#  'भयो': np.int64(5201),
#  'पछि': np.int64(5173),
#  'कुनै': np.int64(5157),
#  'हुन': np.int64(5066),
#  'दिन': np.int64(4930),
#  'नाम': np.int64(4814),
#  'केही': np.int64(4724),
#  'जिल्लाको': np.int64(4724),
#  'जिल्लामा': np.int64(4689),
#  'अवस्थित': np.int64(4541),
#  'वर्ष': np.int64(4478),
#  'अन्य': np.int64(4465),
#  'पहिलो': np.int64(4447),
#  'राष्ट्रिय': np.int64(4408),
#  'सबै': np.int64(4356),
#  'पर्ने': np.int64(4350),
#  'जिल्ला': np.int64(4246),
#  'भएका': np.int64(4229),
#  'विभिन्न': np.int64(4071),
#  'भनिन्छ': np.int64(4011),
#  'क्षेत्र': np.int64(3997),
#  'प्रयोग': np.int64(3975),
#  'राजा': np.int64(3900),
#  'भए': np.int64(3876),
#  'भन्दा': np.int64(3856),
#  'रहेका': np.int64(3789),
#  'जुन': np.int64(3750),
#  'मात्र': np.int64(3691),
#  'प्रमुख': np.int64(3688),
#  'समिति': np.int64(3641),
#  'सम्म': np.int64(3600),
#  'कारण': np.int64(3591),
#  'प्राप्त': np.int64(3589),
#  'रुपमा': np.int64(3479),
#  'गाउँ': np.int64(3472),
#  'गरेर': np.int64(3463),
#  'क्षेत्रमा': np.int64(3439),
#  'यसलाई': np.int64(3402),
#  'राज्य': np.int64(3297),
#  'नेपालमा': np.int64(3255),
#  'आदि': np.int64(3215),
#  'पाइन्छ': np.int64(3195),
#  'साथै': np.int64(3189),
#  'फुटबल': np.int64(3162),
#  'यी': np.int64(3161),
#  'सकिन्छ': np.int64(3155),
#  'गर्दछ': np.int64(3144),
#  'भारतीय': np.int64(3121),
#  'का': np.int64(3089),
#  'दुई': np.int64(3060),
#  'काम': np.int64(3043),
#  'स्थापना': np.int64(3033),
#  'भारतको': np.int64(3028),
#  'वटा': np.int64(3005),
#  'ठूलो': np.int64(2984),
#  'यहाँ': np.int64(2950),
#  'मुख्य': np.int64(2932),
#  'सबैभन्दा': np.int64(2884),
#  'कुरा': np.int64(2870),
#  'समेत': np.int64(2812),
#  'गर्दा': np.int64(2810),
#  'गर्नु': np.int64(2782),
#  'विसं': np.int64(2771),
#  'मन्दिर': np.int64(2743),
#  'संवत्': np.int64(2743),
#  'कि': np.int64(2740),
#  'त्यो': np.int64(2740),
#  'गर्दै': np.int64(2739),
#  'बाट': np.int64(2710),
#  'समयमा': np.int64(2670),
#  'छैन': np.int64(2632),
#  'अथवा': np.int64(2608),
#  'चलचित्र': np.int64(2592),
#  'जो': np.int64(2586),
#  'महिला': np.int64(2578),
#  'यदि': np.int64(2571),
#  'निर्माण': np.int64(2570),
#  'त्यस': np.int64(2555),
#  'सालमा': np.int64(2540),
#  'जन्म': np.int64(2483),
#  'उक्त': np.int64(2454),
#  'समय': np.int64(2335),
#  'उनलाई': np.int64(2320),
#  'भाषा': np.int64(2318),
#  'मानिन्छ': np.int64(2312),
#  'जस्तै': np.int64(2300),
#  'कार्य': np.int64(2283),
#  'एवं': np.int64(2270),
#  'ले': np.int64(2268),
#  'सूचना': np.int64(2230),
#  'बढी': np.int64(2227),
#  'नयाँ': np.int64(2207),
#  'नगरपालिका': np.int64(2188),
#  'यसले': np.int64(2186),
#  'हुन्छन्': np.int64(2178),
#  'प्रसिद्ध': np.int64(2131),
#  'मध्य': np.int64(2076),
#  'भाग': np.int64(2055),
#  'पूर्व': np.int64(2044),
#  'जनसङ्ख्या': np.int64(2032),
#  'तीन': np.int64(2027),
#  'भनेर': np.int64(2023),
#  'यसमा': np.int64(2022),
#  'दक्षिण': np.int64(2018),
#  'घर': np.int64(2003),
#  'अर्को': np.int64(1998),
#  'हाल': np.int64(1981),
#  'भएर': np.int64(1958),
#  'यसका': np.int64(1957),
#  'द्वारा': np.int64(1953),
#  'पृष्ठ': np.int64(1943),
#  'आएको': np.int64(1939),
#  'अञ्चलको': np.int64(1933),
#  'गते': np.int64(1931),
#  'त': np.int64(1930),
#  'श्री': np.int64(1930),
#  'साथ': np.int64(1928),
#  'राजनीतिक': np.int64(1917),
#  'आधारमा': np.int64(1916),
#  'पूजा': np.int64(1913),
#  'लाई': np.int64(1905),
#  'विशेष': np.int64(1886),
#  'पर्दछ': np.int64(1883),
#  'प्राचीन': np.int64(1880),
#  'गर्दछन्': np.int64(1868),
#  'ठाउँमा': np.int64(1850),
#  'जस्ता': np.int64(1835),
#  'गाविस': np.int64(1830),
#  'सदस्य': np.int64(1826),
#  'भारत': np.int64(1824),
#  'उत्तर': np.int64(1821),
#  'तपाईँ': np.int64(1812),
#  'सेवा': np.int64(1807),
#  'विश्व': np.int64(1803),
#  'पहिले': np.int64(1802),
#  'उनका': np.int64(1789),
#  'जनगणना': np.int64(1753),
#  'सफल': np.int64(1753),
#  'छन': np.int64(1751),
#  'भाषाको': np.int64(1740),
#  'उल्लेख': np.int64(1728),
#  'काठमाडौं': np.int64(1724),
#  'प्रकाशित': np.int64(1724),
#  'जसको': np.int64(1715),
#  'द': np.int64(1703),
#  'यसै': np.int64(1688),
#  'प्रकारको': np.int64(1684),
#  'अन्तर्गत': np.int64(1642),
#  'नदी': np.int64(1640),
#  'जसले': np.int64(1636),
#  'पटक': np.int64(1635),
#  'के': np.int64(1633),
#  'प्रदान': np.int64(1616),
#  'भारतमा': np.int64(1605),
#  'धार्मिक': np.int64(1602),
#  'दोस्रो': np.int64(1592),
#  'खेल': np.int64(1590),
#  'कुल': np.int64(1588),
#  'प्रकार': np.int64(1583),
#  'उच्च': np.int64(1570),
#  'क्षेत्रको': np.int64(1568),
#  'अन्तर्राष्ट्रिय': np.int64(1555),
#  'संयुक्त': np.int64(1552),
#  'इतिहास': np.int64(1539),
#  'भगवान': np.int64(1539),
#  'भित्र': np.int64(1532),
#  'हिन्दू': np.int64(1532),
#  'देखिन्छ': np.int64(1531),
#  'गर्छ': np.int64(1526),
#  'जसमा': np.int64(1524),
#  'ती': np.int64(1510),
#  'स्थानीय': np.int64(1502),
#  'साल': np.int64(1500),
#  'मध्ये': np.int64(1479),
#  'पाइने': np.int64(1473),
#  'शिक्षा': np.int64(1473),
#  'पश्चिम': np.int64(1468),
#  'चार': np.int64(1467),
#  'यस्तो': np.int64(1464),
#  'गर्यो': np.int64(1463),
#  'लेख': np.int64(1457),
#  'स्थान': np.int64(1454),
#  'त्यसैले': np.int64(1439),
#  'आर्थिक': np.int64(1433),
#  'धर्म': np.int64(1427),
#  'अध्ययन': np.int64(1420),
#  'त्यसको': np.int64(1416),
#  'अर्थ': np.int64(1406),
#  'त्यसपछि': np.int64(1406),
#  'प्रत्येक': np.int64(1400),
#  'विक्रम': np.int64(1392),
#  'अन्तिम': np.int64(1390),
#  'गाँउ': np.int64(1389),
#  'गरियो': np.int64(1387),
#  'व्यवस्था': np.int64(1386),
#  'सम्पादन': np.int64(1386),
#  'अफ': np.int64(1381),
#  'नेपालका': np.int64(1381),
#  'आफ्ना': np.int64(1377),
#  'लामो': np.int64(1377),
#  'सामाजिक': np.int64(1373),
#  'राष्ट्र': np.int64(1372),
#  'थिइन्': np.int64(1370),
#  'पुरुष': np.int64(1370),
#  'हुँदै': np.int64(1369),
#  'घोषणा': np.int64(1365),
#  'यसरी': np.int64(1363),
#  'बनेको': np.int64(1360),
#  'स्थानमा': np.int64(1353),
#  'गरि': np.int64(1346),
#  'पत्रिकाको': np.int64(1346),
#  'पुरस्कार': np.int64(1339),
#  'स्थित': np.int64(1331),
#  'कम': np.int64(1322),
#  'पर्छ': np.int64(1317),
#  'पानी': np.int64(1303),
#  'हजार': np.int64(1303),
#  'सक्छ': np.int64(1296),
#  'महत्वपूर्ण': np.int64(1295),
#  'विवाह': np.int64(1274),
#  'जसलाई': np.int64(1269),
#  'बसोबास': np.int64(1268),
#  'बारेमा': np.int64(1265),
#  'प्रथम': np.int64(1262),
#  'वर्षको': np.int64(1261),
#  'नामक': np.int64(1254),
#  'छोरा': np.int64(1250),
#  'गीत': np.int64(1247),
#  'ऐतिहासिक': np.int64(1239),
#  'राम्रो': np.int64(1239),
#  'केन्द्र': np.int64(1233),
#  'निकै': np.int64(1224),
#  'राजधानी': np.int64(1217),
#  'स्थापित': np.int64(1208),
#  'बेला': np.int64(1203),
#  'भई': np.int64(1203),
#  'दिने': np.int64(1195),
#  'म': np.int64(1191),
#  'खेलाडी': np.int64(1185),
#  'लगभग': np.int64(1185),
#  'प्रधानमन्त्री': np.int64(1182),
#  'अतिरिक्त': np.int64(1181),
#  'अहिले': np.int64(1177),
#  'क्रममा': np.int64(1175),
#  'क्रिकेट': np.int64(1170),
#  'प्रवेश': np.int64(1163),
#  'मृत्यु': np.int64(1158),
#  'तत्कालीन': np.int64(1153),
#  'जना': np.int64(1150),
#  'सय': np.int64(1141),
#  'कथा': np.int64(1140),
#  'भागमा': np.int64(1138),
#  'शब्द': np.int64(1138),
#  'सुरु': np.int64(1134),
#  'जब': np.int64(1128),
#  'हुँदा': np.int64(1127),
#  'अनि': np.int64(1126),
#  'लिखित': np.int64(1120),
#  'प्रकाशन': np.int64(1110),
#  'अगाडि': np.int64(1109),
#  'भाषामा': np.int64(1094),
#  'माथि': np.int64(1092),
#  'शासन': np.int64(1090),
#  'सानो': np.int64(1089),
#  'न': np.int64(1085),
#  'भएपछि': np.int64(1083),
#  'टिम': np.int64(1077),
#  'सो': np.int64(1077),
#  'शहर': np.int64(1067),
#  'गर्छन्': np.int64(1065),
#  'जीवन': np.int64(1062),
#  'मानव': np.int64(1058),
#  'लेखिएको': np.int64(1058),
#  'करिब': np.int64(1056),
#  'पूर्वी': np.int64(1056),
#  'थापा': np.int64(1051),
#  'उत्पादन': np.int64(1045),
#  'दिए': np.int64(1044),
#  'चलन': np.int64(1041),
#  'त्यस्तै': np.int64(1041),
#  'राज्यको': np.int64(1039),
#  'अधिकार': np.int64(1038),
#  'देश': np.int64(1037),
#  'नामले': np.int64(1037),
#  'प्रति': np.int64(1035),
#  'लिएर': np.int64(1035),
#  'अवस्थामा': np.int64(1031),
#  'भएकाले': np.int64(1030),
#  'गरिने': np.int64(1023),
#  'जस्तो': np.int64(1011),
#  'युद्ध': np.int64(1011),
#  'आएका': np.int64(1003),
#  'यही': np.int64(1000),
#  'पुरानो': np.int64(998),
#  'त्यहाँ': np.int64(997),
#  'थाले': np.int64(997),
#  'चाँडै': np.int64(996),
#  'विश्वास': np.int64(996),
#  'सम्पूर्ण': np.int64(994),
#  'आउने': np.int64(991),
#  'संविधान': np.int64(989),
#  'विचार': np.int64(985),
#  'गएको': np.int64(979),
#  'नं': np.int64(974),
#  'जहाँ': np.int64(973),
#  'शक': np.int64(969),
#  'सहमत': np.int64(966),
#  'क्याम्पस': np.int64(963),
#  'विश्वविद्यालय': np.int64(962),
#  'खेलमा': np.int64(955),
#  'ईपू': np.int64(951),
#  'उपन्यास': np.int64(945),
#  'जाने': np.int64(944),
#  'विद्यालय': np.int64(942),
#  'गोल': np.int64(939),
#  'सँग': np.int64(937),
#  'पार्टी': np.int64(935),
#  'हुनु': np.int64(935),
#  'सहयोग': np.int64(934),
#  'पहाडी': np.int64(931),
#  'अभिनेत्री': np.int64(929),
#  'हेर्नुहोला': np.int64(929),
#  'मान्यता': np.int64(927),
#  'यात्रा': np.int64(927),
#  'रोग': np.int64(927),
#  'शुरु': np.int64(925),
#  'लगायत': np.int64(923),
#  'यहाँको': np.int64(921),
#  'सञ्चालन': np.int64(921),
#  'अञ्चल': np.int64(920),
#  'कारणले': np.int64(920),
#  'मेटाउन': np.int64(918),
#  'परेको': np.int64(917),
#  'प्रतिशत': np.int64(913),
#  'भनेको': np.int64(911),
#  'सिंह': np.int64(911),
#  'हुनाले': np.int64(908),
#  'तपाईँले': np.int64(907),
#  'मेटाउनु': np.int64(905),
#  'सहर': np.int64(905),
#  'त्रिभुवन': np.int64(904),
#  'वार्तालापमा': np.int64(901),
#  'गरेकी': np.int64(899),
#  'अर्थात्': np.int64(895),
#  'लाख': np.int64(889),
#  'अघि': np.int64(888),
#  'गएर': np.int64(888),
#  'दुवै': np.int64(888),
#  'कम्पनी': np.int64(885),
#  'त्यही': np.int64(884),
#  'पत्रिका': np.int64(881),
#  'लाग्ने': np.int64(880),
#  'सम्पन्न': np.int64(879),
#  'निश्चित': np.int64(878),
#  'महिना': np.int64(878),
#  'राख्न': np.int64(877),
#  'सामान्य': np.int64(875),
#  'क्लब': np.int64(873),
#  'निर्वाचन': np.int64(871),
#  'लिएको': np.int64(870),
#  'अध्यक्ष': np.int64(867),
#  'अमेरिकी': np.int64(867),
#  'पाँच': np.int64(867),
#  'आयोजना': np.int64(863),
#  'औं': np.int64(863),
#  'बजार': np.int64(863),
#  'हेर्न': np.int64(862),
#  'गयो': np.int64(861),
#  'तल': np.int64(860),
#  'शाह': np.int64(860),
#  'सालको': np.int64(860),
#  'प्राकृतिक': np.int64(859),
#  'आधुनिक': np.int64(858),
#  'या': np.int64(858),
#  'सरकारी': np.int64(856),
#  'प्रचलित': np.int64(852),
#  'अधिकांश': np.int64(850),
#  'वर्ग': np.int64(848),
#  'नैं': np.int64(847),
#  'जम्मा': np.int64(846),
#  'प्रहरी': np.int64(846),
#  'बनाइएको': np.int64(846),
#  'हरेक': np.int64(846),
#  'तयार': np.int64(843),
#  'मिटर': np.int64(841),
#  'आधारित': np.int64(839),
#  'गाविसको': np.int64(839),
#  'सरकार': np.int64(838),
#  'सम्बन्धित': np.int64(837),
#  'घरमा': np.int64(835),
#  'तिर': np.int64(833),
#  'तेस्रो': np.int64(827),
#  'पश्चिममा': np.int64(827),
#  'गाविसमा': np.int64(824),
#  'बौद्ध': np.int64(824),
#  'सांस्कृतिक': np.int64(824),
#  'किलोमिटर': np.int64(820),
#  'ताल': np.int64(818),
#  'भएकोले': np.int64(818),
#  'आफ्नै': np.int64(816),
#  'बजारमा': np.int64(816),
#  'बनाउने': np.int64(812),
#  'भूमिका': np.int64(811),
#  'उपलब्ध': np.int64(809),
#  'आज': np.int64(808),
#  'व्यक्ति': np.int64(808),
#  'सरकारले': np.int64(808),
#  'शक्ति': np.int64(807),
#  'हुनुहुन्छ': np.int64(807),
#  'सार्वजनिक': np.int64(806),
#  'जनसंख्या': np.int64(805),
#  'भनी': np.int64(805),
#  'सम्बन्ध': np.int64(804),
#  'गई': np.int64(802),
#  'सदरमुकाम': np.int64(802),
#  'सम्पदा': np.int64(800),
#  'कर्णाली': np.int64(799),
#  'सुधार': np.int64(796),
#  'प्रस्तुत': np.int64(795),
#  'निम्न': np.int64(794),
#  'पूर्ण': np.int64(794),
#  'आवश्यक': np.int64(792),
#  'मन': np.int64(792),
#  'मानिसहरू': np.int64(792),
#  'आउँछ': np.int64(791),
#  'केन्द्रीय': np.int64(791),
#  'साझा': np.int64(790),
#  'अङ्ग्रेजी': np.int64(786),
#  'देशको': np.int64(786),
#  'उत्तरी': np.int64(782),
#  'त्यसै': np.int64(778),
#  'हिमाल': np.int64(778),
#  'परम्परा': np.int64(775),
#  'प्रतियोगिता': np.int64(773),
#  'समाचार': np.int64(773),
#  'अब': np.int64(772),
#  'कायम': np.int64(772),
#  'तर्फ': np.int64(772),
#  'बनाउन': np.int64(772),
#  'सहित': np.int64(767),
#  'कार्यक्रम': np.int64(766),
#  'पर्व': np.int64(766),
#  'पूरा': np.int64(766),
#  'उत्पन्न': np.int64(764),
#  'नदीको': np.int64(764),
#  'विभाजन': np.int64(764),
#  'सन': np.int64(764),
#  'उत्कृष्ट': np.int64(763),
#  'विज्ञान': np.int64(762),
#  'हाम्रो': np.int64(762),
#  'वडा': np.int64(761),
#  'कृष्ण': np.int64(759),
#  'लागी': np.int64(758),
#  'ठाउँ': np.int64(751),
#  'कृषि': np.int64(749),
#  'यस्ता': np.int64(748),
#  'ठुलो': np.int64(747),
#  'परिवर्तन': np.int64(747),
#  'पूर्वमा': np.int64(746),
#  'दक्षिणमा': np.int64(745),
#  'मेरो': np.int64(745),
#  'रेडियो': np.int64(744),
#  'राख्ने': np.int64(742),
#  'गाउँपालिका': np.int64(740),
#  'बीच': np.int64(740),
#  'वर्णन': np.int64(736),
#  'पर्न': np.int64(734),
#  'वर्तमान': np.int64(734),
#  'अस्पताल': np.int64(732),
#  'रूप': np.int64(731),
#  'राखिएको': np.int64(730),
#  'राणा': np.int64(727),
#  'प्रदेश': np.int64(726),
#  'व्यक्त': np.int64(725),
#  'निर्णय': np.int64(722),
#  'बाहिर': np.int64(721),
#  'रचना': np.int64(721),
#  'कुराको': np.int64(720),
#  'उत्तरमा': np.int64(719),
#  'मूल': np.int64(719),
#  'संस्कृत': np.int64(717),
#  'थाहा': np.int64(716),
#  'कविता': np.int64(714),
#  'आमा': np.int64(713),
#  'गौतम': np.int64(712),
#  'थिएन': np.int64(712),
#  'हामी': np.int64(709),
#  'स्वतन्त्र': np.int64(707),
#  'गए': np.int64(706),
#  'सक्ने': np.int64(706),
#  'कलेज': np.int64(705),
#  'लगायतका': np.int64(705),
#  'कुरामा': np.int64(699),
#  'जान्छ': np.int64(698),
#  'अभिनय': np.int64(697),
#  'दिएको': np.int64(697),
#  'भनिएको': np.int64(697),
#  'लिन': np.int64(696),
#  'गठन': np.int64(695),
#  'क्षेत्रफल': np.int64(693),
#  'परिवार': np.int64(693),
#  'प्रतिनिधित्व': np.int64(692),
#  'अमेरिकन': np.int64(691),
#  'ज्ञान': np.int64(691),
#  'फरक': np.int64(691),
#  'भारतका': np.int64(691),
#  'संख्या': np.int64(691),
#  'नगरपालिकाको': np.int64(690),
#  'पर्याप्त': np.int64(689),
#  'लिग': np.int64(688),
#  'कार्यालय': np.int64(685),
#  'चराको': np.int64(685),
#  'अनेक': np.int64(684),
#  'राष्ट्रपति': np.int64(684),
#  'खण्डमा': np.int64(683),
#  'लेखक': np.int64(681),
#  'संस्था': np.int64(681),
#  'यहाँका': np.int64(680),
#  'गरेपछि': np.int64(672),
#  'बाहेक': np.int64(671),
#  'बागमती': np.int64(670),
#  'प्रकारका': np.int64(668),
#  'प्रसाद': np.int64(668),
#  'हुँदैन': np.int64(668),
#  'बन्न': np.int64(667),
#  'ल्याएको': np.int64(664),
#  'संग': np.int64(661),
#  'स्वास्थ्य': np.int64(661),
#  'पवित्र': np.int64(660),
#  'बनेका': np.int64(660),
#  'लिने': np.int64(660),
#  'पूर्वका': np.int64(659),
#  'चर्चित': np.int64(658),
#  'थुप्रै': np.int64(658),
#  'मन्दिरमा': np.int64(658),
#  'सं': np.int64(658),
#  'उपन्यासकार': np.int64(655),
#  'जोडिएको': np.int64(655),
#  'योगदान': np.int64(655),
#  'अत्यन्त': np.int64(654),
#  'स्थल': np.int64(654),
#  'आधार': np.int64(653),
#  'प्रभाव': np.int64(653),
#  'अवस्था': np.int64(652),
#  'क्यालेण्डर': np.int64(649),
#  'दर्शन': np.int64(649),
#  'प्रकाशक': np.int64(648),
#  'होइन': np.int64(646),
#  'साहित्य': np.int64(644),
#  'गरिएका': np.int64(642),
#  'मिलेर': np.int64(641),
#  'राम': np.int64(640),
#  'ईसाको': np.int64(637),
#  'उमेरमा': np.int64(634),
#  'संस्कृति': np.int64(634),
#  'सक्नुहुन्छ': np.int64(634),
#  'अधिक': np.int64(631),
#  'दिएका': np.int64(631),
#  'बनाएर': np.int64(631),
#  'यिनको': np.int64(630),
#  'केवल': np.int64(629),
#  'पुगेको': np.int64(629),
#  'बीचमा': np.int64(628),
#  'मानिस': np.int64(628),
#  'पहिला': np.int64(627),
#  'अरु': np.int64(625),
#  'उहाँ': np.int64(625),
#  'बस्ने': np.int64(625),
#  'समूह': np.int64(625),
#  'माध्यमिक': np.int64(623),
#  'आएर': np.int64(622),
#  'छोरी': np.int64(620),
#  'प्रधान': np.int64(620),
#  'कृति': np.int64(619),
#  'बने': np.int64(618),
#  'सम्मान': np.int64(618),
#  'बाटो': np.int64(617),
#  'विश्वमा': np.int64(617),
#  'जाति': np.int64(616),
#  'जन्मदेखि': np.int64(615),
#  'अर्थात': np.int64(612),
#  'सात': np.int64(612),
#  'पछी': np.int64(611),
#  'सप्तर्षि': np.int64(611),
#  'काठमाडौंमा': np.int64(610),
#  'खोला': np.int64(610),
#  'देशमा': np.int64(609),
#  'निर्वाचित': np.int64(609),
#  'अलग': np.int64(608),
#  'कोशी': np.int64(607),
#  'सगरमाथा': np.int64(607),
#  'उपाधि': np.int64(606),
#  'ललितपुर': np.int64(606),
#  'लुम्बिनी': np.int64(603),
#  'पुस्तक': np.int64(602),
#  'आक्रमण': np.int64(601),
#  'फल': np.int64(601),
#  'लागेको': np.int64(601),
#  'संरक्षण': np.int64(601),
#  'त्यसलाई': np.int64(598),
#  'सुन्दर': np.int64(598),
#  'जारी': np.int64(597),
#  'पुराना': np.int64(597),
#  'पर्वत': np.int64(595),
#  'पुत्र': np.int64(592),
#  'सरकारको': np.int64(592),
#  'बनाएको': np.int64(590),
#  'नामबाट': np.int64(589),
#  'शान्ति': np.int64(589),
#  'अङ्ग्रेजीमा': np.int64(588),
#  'दल': np.int64(587),
#  'बनाउनु': np.int64(587),
#  'क्षेत्रका': np.int64(586),
#  'नगर': np.int64(586),
#  'सभा': np.int64(582),
#  'एकपटक': np.int64(581),
#  'डा': np.int64(581),
#  'रहन': np.int64(581),
#  'रातो': np.int64(581),
#  'आरम्भ': np.int64(578),
#  'जानकारी': np.int64(578),
#  'बहादुर': np.int64(578),
#  'प्रतिक्रिया': np.int64(577),
#  'डोटी': np.int64(573),
#  'फैलिएको': np.int64(572),
#  'सृजना': np.int64(572),
#  'चिनिन्छ': np.int64(571),
#  'छिन्': np.int64(570),
#  'देवता': np.int64(569),
#  'सुरू': np.int64(569),
#  'देवी': np.int64(568),
#  'लोकप्रिय': np.int64(568),
#  'आधिकारिक': np.int64(566),
#  'राजाको': np.int64(566),
#  'दिइएको': np.int64(565),
#  'श्रेष्ठ': np.int64(565),
#  'पिता': np.int64(564),
#  'रहने': np.int64(564),
#  'मत': np.int64(563),
#  'वैज्ञानिक': np.int64(563),
#  'युवा': np.int64(562),
#  'विजय': np.int64(561),
#  'साना': np.int64(561),
#  'नेता': np.int64(560),
#  'देखेर': np.int64(559),
#  'रहन्छ': np.int64(559),
#  'खेल्ने': np.int64(558),
#  'मैले': np.int64(558),
#  'समस्या': np.int64(558),
#  'पाल्पा': np.int64(557),
#  'मल्ल': np.int64(556),
#  'प्राय': np.int64(555),
#  'नेकपा': np.int64(554),
#  'वेब': np.int64(554),
#  'थप': np.int64(553),
#  'अति': np.int64(552),
#  'विषयमा': np.int64(552),
#  'करोड': np.int64(550),
#  'प्रतियोगितामा': np.int64(550),
#  'मात्रै': np.int64(550),
#  'निम्ति': np.int64(549),
#  'यिनी': np.int64(548),
#  'हिन्दी': np.int64(548),
#  'दिनमा': np.int64(545),
#  'नुवाकोट': np.int64(545),
#  'युद्धमा': np.int64(544),
#  'हात': np.int64(544),
#  'चलचित्रमा': np.int64(543),
#  'जनवरी': np.int64(542),
#  'मन्दिरको': np.int64(541),
#  'संघको': np.int64(541),
#  'सक्रिय': np.int64(541),
#  'दरबार': np.int64(538),
#  'उनीहरू': np.int64(537),
#  'ठूला': np.int64(536),
#  'उपत्यका': np.int64(535),
#  'प्रत्यक्ष': np.int64(535),
#  'फेरि': np.int64(535),
#  'वि': np.int64(534),
#  'राजाले': np.int64(533),
#  'फिफा': np.int64(532),
#  'शिव': np.int64(532),
#  'इतिहासमा': np.int64(531),
#  'अमेरिका': np.int64(530),
#  'पश्चिमाञ्चल': np.int64(530),
#  'ढाँचा': np.int64(529),
#  'थर': np.int64(528),
#  'महत्व': np.int64(528),
#  'आफूलाई': np.int64(527),
#  'एउटै': np.int64(527),
#  'जति': np.int64(527),
#  'रूपले': np.int64(526),
#  'हुनेछ': np.int64(526),
#  'गराउने': np.int64(525),
#  'सन्तान': np.int64(524),
#  'हिन्दु': np.int64(524),
#  'अग्लो': np.int64(523),
#  'उनि': np.int64(523),
#  'तब': np.int64(523),
#  'अनुमान': np.int64(522),
#  'प्रबन्धक': np.int64(522),
#  'लागू': np.int64(521),
#  'गर्छन': np.int64(520),
#  'जुम्ला': np.int64(520),
#  'उपचार': np.int64(519),
#  'मगर': np.int64(519),
#  'पर्दछन्': np.int64(518),
#  'पुनः': np.int64(518),
#  'सम्बन्धन': np.int64(518),
#  'आफैले': np.int64(517),
#  'पश्चिमी': np.int64(517),
#  'रहे': np.int64(517),
#  'गर्नको': np.int64(516),
#  'पुन': np.int64(515),
#  'खान': np.int64(514),
#  'मापदण्ड': np.int64(514),
#  'खाने': np.int64(513),
#  'ध्यान': np.int64(513),
#  'कालमा': np.int64(512),
#  'केहि': np.int64(512),
#  'अवधिमा': np.int64(511),
#  'विश्वको': np.int64(511),
#  'कवि': np.int64(510),
#  'डिग्री': np.int64(510),
#  'उपयोग': np.int64(509),
#  'भक्तपुर': np.int64(509),
#  'मात्रामा': np.int64(509),
#  'समाजमा': np.int64(508),
#  'देख्न': np.int64(507),
#  'समावेश': np.int64(507),
#  'स्पष्ट': np.int64(507),
#  'किन': np.int64(505),
#  'राजनीतिमा': np.int64(505),
#  'सिधै': np.int64(505),
#  'आचार्य': np.int64(504),
#  'जनताको': np.int64(504),
#  'धर्मको': np.int64(504),
#  'सङ्गठन': np.int64(504),
#  'सैनिक': np.int64(504),
#  'उसको': np.int64(503),
#  'कृपया': np.int64(503),
#  'सडक': np.int64(503),
#  'पार्टीको': np.int64(502),
#  'माओवादी': np.int64(502),
#  'लगाउने': np.int64(502),
#  'क्षमता': np.int64(501),
#  'जातिको': np.int64(500),
#  'भन्नाले': np.int64(500),
#  'संस्कार': np.int64(500),
#  'सेतो': np.int64(500),
#  'सेना': np.int64(498),
#  'निर्वाचनमा': np.int64(497),
#  'प्रचलन': np.int64(497),
#  'फूल': np.int64(497),
#  'भन्न': np.int64(497),
#  'मनाउने': np.int64(497),
#  'खस': np.int64(495),
#  'प्रकाशनले': np.int64(495),
#  'जीवनको': np.int64(494),
#  'ब्रिटिश': np.int64(494),
#  'वैदिक': np.int64(494),
#  'आन्दोलन': np.int64(493),
#  'प्रयास': np.int64(493),
#  'विरुद्ध': np.int64(493),
#  'गण्डकी': np.int64(490),
#  'नियम': np.int64(490),
#  'पाउने': np.int64(490),
#  'मन्त्री': np.int64(490),
#  'सबभन्दा': np.int64(490),
#  'सहभागी': np.int64(490),
#  'जिल्लाका': np.int64(489),
#  'पुगे': np.int64(489),
#  'वनस्पति': np.int64(487),
#  'समाज': np.int64(487),
#  'पर्यटकीय': np.int64(486),
#  'बैंक': np.int64(486),
#  'मेला': np.int64(486),
#  'सम्बन्धी': np.int64(486),
#  'कला': np.int64(485),
#  'राज्यमा': np.int64(484),
#  'साधारण': np.int64(484),
#  'प्रणाली': np.int64(483),
#  'भौगोलिक': np.int64(483),
#  'झापा': np.int64(482),
#  'तत्कालिन': np.int64(482),
#  'मार्च': np.int64(482),
#  'विषय': np.int64(482),
#  'तर्फबाट': np.int64(481),
#  'पुग्यो': np.int64(481),
#  'विकसित': np.int64(481),
#  'सर्वाधिक': np.int64(481),
#  'भौतिक': np.int64(480),
#  'गर्नका': np.int64(479),
#  'ब्राह्मण': np.int64(479),
#  'माघ': np.int64(479),
#  'हेर्दा': np.int64(479),
#  'आए': np.int64(478),
#  'गणना': np.int64(478),
#  'हासिल': np.int64(478),
#  'गुगल': np.int64(476),
#  'तिनको': np.int64(476),
#  'परम्परागत': np.int64(476),
#  'किमी': np.int64(475),
#  'योजना': np.int64(475),
#  'आधारको': np.int64(474),
#  'जान': np.int64(474),
#  'मे': np.int64(474),
#  'उहाँले': np.int64(473),
#  'हुदै': np.int64(472),
#  'आदिमा': np.int64(471),
#  'उहाँको': np.int64(471),
#  'दक्षिणी': np.int64(471),
#  'पश्चात': np.int64(470),
#  'हे': np.int64(470),
#  'कर': np.int64(469),
#  'नाममा': np.int64(469),
#  'पृष्ठको': np.int64(469),
#  'गुरु': np.int64(468),
#  'सकिनेछ': np.int64(468),
#  'उद्देश्य': np.int64(467),
#  'विशाल': np.int64(467),
#  'सम्मको': np.int64(467),
#  'कसरी': np.int64(466),
#  'समाप्त': np.int64(466),
#  'कालो': np.int64(465),
#  'बटन': np.int64(465),
#  'व्रत': np.int64(465),
#  'बसेको': np.int64(463),
#  'संघ': np.int64(463),
#  'नपरेको': np.int64(462),
#  'मेटाउने': np.int64(462),
#  'लिङ्कहरू': np.int64(462),
#  'मध्येको': np.int64(461),
#  'मानेर': np.int64(461),
#  'यस्तै': np.int64(461),
#  'उनीहरूको': np.int64(460),
#  'गरिन्': np.int64(460),
#  'मलाई': np.int64(460),
#  'मोरङ': np.int64(460),
#  'सम्बत': np.int64(460),
#  'ग्रहण': np.int64(459),
#  'सक्नुहुनेछ': np.int64(459),
#  'अभिनेता': np.int64(458),
#  'नामको': np.int64(458),
#  'डिसेम्बर': np.int64(457),
#  'निर्देशक': np.int64(455),
#  'गर्नुहोला': np.int64(454),
#  'पुरा': np.int64(454),
#  'बन्यो': np.int64(454),
#  'हुनुहुन्न': np.int64(454),
#  'उसले': np.int64(453),
#  'गाउँमा': np.int64(453),
#  'प्रदेशको': np.int64(453),
#  'महेन्द्र': np.int64(453),
#  'समान': np.int64(453),
#  'अझ': np.int64(452),
#  'अझै': np.int64(452),
#  'पाइन्छन्': np.int64(452),
#  'मापदण्डमा': np.int64(452),
#  'शुक्ल': np.int64(452),
#  'अनुपयुक्त': np.int64(451),
#  'धनकुटा': np.int64(451),
#  'मार्फत': np.int64(451),
#  'राखिसकेपछि': np.int64(451),
#  'शर्मा': np.int64(451),
#  'नहटाउनुहोला': np.int64(450),
#  'प्रशासकद्वारा': np.int64(450),
#  'बर्ष': np.int64(450),
#  'थिच्नुहोला': np.int64(449),
#  'युटिसीमा': np.int64(449),
#  'लगहरू': np.int64(449),
#  'विस्तार': np.int64(449),
#  'हटाउनुहोला': np.int64(449),
#  'पष्ठलाई': np.int64(448),
#  'प्रबन्धकहरूको': np.int64(448),
#  'मेटाउनुभन्दा': np.int64(448),
#  'सोही': np.int64(447),
#  'ऋषि': np.int64(446),
#  'चीन': np.int64(446),
#  'नेपालले': np.int64(446),
#  'कानुन': np.int64(444),
#  'नियुक्त': np.int64(443),
#  'राखेर': np.int64(443),
#  'ः': np.int64(442),
#  'शब्दको': np.int64(442),
#  'हिमाली': np.int64(442),
#  'नेतृत्व': np.int64(441),
#  'लामा': np.int64(441),
#  'देखा': np.int64(440),
#  'नम्बर': np.int64(440),
#  'मध्यमाञ्चल': np.int64(440),
#  'यिनले': np.int64(440),
#  'संलग्न': np.int64(440),
#  'सकेको': np.int64(440),
#  'सामान्यतया': np.int64(438),
#  'उद्योग': np.int64(437),
#  'काठमाडौंको': np.int64(436),
#  'आठ': np.int64(435),
#  'जनता': np.int64(435),
#  'थाल्यो': np.int64(435),
#  'पराजित': np.int64(435),
#  'सिन्धुपाल्चोक': np.int64(435),
#  'सुरुवात': np.int64(435),
#  'पहिचान': np.int64(434),
#  'पोखरी': np.int64(434),
#  'हत्या': np.int64(434),
#  'दैलेख': np.int64(433),
#  'परिवारमा': np.int64(433),
#  'विस': np.int64(433),
#  'शुरू': np.int64(433),
#  'शैक्षिक': np.int64(433),
#  'मानिसको': np.int64(432),
#  'एकै': np.int64(431),
#  'नियन्त्रण': np.int64(431),
#  'की': np.int64(430),
#  'दुइ': np.int64(430),
#  'नवलपरासी': np.int64(430),
#  'कपिलवस्तु': np.int64(429),
#  'गर्दथे': np.int64(429),
#  'सुनसरी': np.int64(429),
#  'ईसा': np.int64(428),
#  'खेती': np.int64(428),
#  'चौथो': np.int64(428),
#  'बुद्ध': np.int64(428),
#  'वन': np.int64(428),
#  'गुल्मी': np.int64(427),
#  'ग्रन्थ': np.int64(426),
#  'मुक्त': np.int64(426),
#  'सुबेदी': np.int64(426),
#  'इलाम': np.int64(425),
#  'उपयुक्त': np.int64(424),
#  'पदार्थ': np.int64(424),
#  'मानिएको': np.int64(424),
#  'उपर्युक्त': np.int64(423),
#  'किसिमको': np.int64(423),
#  'दैनिक': np.int64(423),
#  'नीति': np.int64(423),
#  'नागरिक': np.int64(422),
#  'पौराणिक': np.int64(422),
#  'बनाए': np.int64(422),
#  'भवन': np.int64(422),
#  'सहायक': np.int64(422),
#  'अरू': np.int64(420),
#  'टाढा': np.int64(420),
#  'अमेरिकाको': np.int64(419),
#  'जात्रा': np.int64(419),
#  'भूभाग': np.int64(419),
#  'शाही': np.int64(419),
#  'सामूहिक': np.int64(419),
#  'अक्टोबर': np.int64(418),
#  'त्यसमा': np.int64(418),
#  'दिएर': np.int64(418),
#  'कूल': np.int64(417),
#  ...}

# %%
len(WORD_COUNT_DICTIONARY)
# Out:
# 240683

# %%
WORD_COUNT_DICTIONARY
# Out:
# {'र': np.int64(71188),
#  'छ': np.int64(40288),
#  'हो': np.int64(38885),
#  'यो': np.int64(29268),
#  'पनि': np.int64(28314),
#  'एक': np.int64(23869),
#  'थियो': np.int64(19582),
#  'यस': np.int64(18421),
#  'मा': np.int64(17689),
#  'तथा': np.int64(17604),
#  'भएको': np.int64(17383),
#  'थिए': np.int64(14992),
#  'छन्': np.int64(14750),
#  'रहेको': np.int64(13554),
#  'को': np.int64(12720),
#  'लागि': np.int64(12437),
#  'भने': np.int64(11554),
#  'हुन्छ': np.int64(11381),
#  'गर्ने': np.int64(9930),
#  'आफ्नो': np.int64(9446),
#  'रूपमा': np.int64(9303),
#  'गर्न': np.int64(9063),
#  'वा': np.int64(8942),
#  'हुन्': np.int64(8546),
#  'नेपालको': np.int64(8316),
#  'नेपाली': np.int64(7924),
#  'सन्': np.int64(7880),
#  'नै': np.int64(7675),
#  'विकास': np.int64(7671),
#  'गरेको': np.int64(7297),
#  'उनले': np.int64(7209),
#  'यसको': np.int64(6936),
#  'गरिएको': np.int64(6804),
#  'तर': np.int64(6703),
#  'गरेका': np.int64(6584),
#  'नेपाल': np.int64(6422),
#  'उनी': np.int64(6122),
#  'अनुसार': np.int64(5989),
#  'गरे': np.int64(5935),
#  'भन्ने': np.int64(5917),
#  'हुने': np.int64(5894),
#  'देखि': np.int64(5836),
#  'एउटा': np.int64(5660),
#  'धेरै': np.int64(5563),
#  'गरी': np.int64(5500),
#  'उनको': np.int64(5442),
#  'गरिन्छ': np.int64(5269),
#  'भयो': np.int64(5201),
#  'पछि': np.int64(5173),
#  'कुनै': np.int64(5157),
#  'हुन': np.int64(5066),
#  'दिन': np.int64(4930),
#  'नाम': np.int64(4814),
#  'केही': np.int64(4724),
#  'जिल्लाको': np.int64(4724),
#  'जिल्लामा': np.int64(4689),
#  'अवस्थित': np.int64(4541),
#  'वर्ष': np.int64(4478),
#  'अन्य': np.int64(4465),
#  'पहिलो': np.int64(4447),
#  'राष्ट्रिय': np.int64(4408),
#  'सबै': np.int64(4356),
#  'पर्ने': np.int64(4350),
#  'जिल्ला': np.int64(4246),
#  'भएका': np.int64(4229),
#  'विभिन्न': np.int64(4071),
#  'भनिन्छ': np.int64(4011),
#  'क्षेत्र': np.int64(3997),
#  'प्रयोग': np.int64(3975),
#  'राजा': np.int64(3900),
#  'भए': np.int64(3876),
#  'भन्दा': np.int64(3856),
#  'रहेका': np.int64(3789),
#  'जुन': np.int64(3750),
#  'मात्र': np.int64(3691),
#  'प्रमुख': np.int64(3688),
#  'समिति': np.int64(3641),
#  'सम्म': np.int64(3600),
#  'कारण': np.int64(3591),
#  'प्राप्त': np.int64(3589),
#  'रुपमा': np.int64(3479),
#  'गाउँ': np.int64(3472),
#  'गरेर': np.int64(3463),
#  'क्षेत्रमा': np.int64(3439),
#  'यसलाई': np.int64(3402),
#  'राज्य': np.int64(3297),
#  'नेपालमा': np.int64(3255),
#  'आदि': np.int64(3215),
#  'पाइन्छ': np.int64(3195),
#  'साथै': np.int64(3189),
#  'फुटबल': np.int64(3162),
#  'यी': np.int64(3161),
#  'सकिन्छ': np.int64(3155),
#  'गर्दछ': np.int64(3144),
#  'भारतीय': np.int64(3121),
#  'का': np.int64(3089),
#  'दुई': np.int64(3060),
#  'काम': np.int64(3043),
#  'स्थापना': np.int64(3033),
#  'भारतको': np.int64(3028),
#  'वटा': np.int64(3005),
#  'ठूलो': np.int64(2984),
#  'यहाँ': np.int64(2950),
#  'मुख्य': np.int64(2932),
#  'सबैभन्दा': np.int64(2884),
#  'कुरा': np.int64(2870),
#  'समेत': np.int64(2812),
#  'गर्दा': np.int64(2810),
#  'गर्नु': np.int64(2782),
#  'विसं': np.int64(2771),
#  'मन्दिर': np.int64(2743),
#  'संवत्': np.int64(2743),
#  'कि': np.int64(2740),
#  'त्यो': np.int64(2740),
#  'गर्दै': np.int64(2739),
#  'बाट': np.int64(2710),
#  'समयमा': np.int64(2670),
#  'छैन': np.int64(2632),
#  'अथवा': np.int64(2608),
#  'चलचित्र': np.int64(2592),
#  'जो': np.int64(2586),
#  'महिला': np.int64(2578),
#  'यदि': np.int64(2571),
#  'निर्माण': np.int64(2570),
#  'त्यस': np.int64(2555),
#  'सालमा': np.int64(2540),
#  'जन्म': np.int64(2483),
#  'उक्त': np.int64(2454),
#  'समय': np.int64(2335),
#  'उनलाई': np.int64(2320),
#  'भाषा': np.int64(2318),
#  'मानिन्छ': np.int64(2312),
#  'जस्तै': np.int64(2300),
#  'कार्य': np.int64(2283),
#  'एवं': np.int64(2270),
#  'ले': np.int64(2268),
#  'सूचना': np.int64(2230),
#  'बढी': np.int64(2227),
#  'नयाँ': np.int64(2207),
#  'नगरपालिका': np.int64(2188),
#  'यसले': np.int64(2186),
#  'हुन्छन्': np.int64(2178),
#  'प्रसिद्ध': np.int64(2131),
#  'मध्य': np.int64(2076),
#  'भाग': np.int64(2055),
#  'पूर्व': np.int64(2044),
#  'जनसङ्ख्या': np.int64(2032),
#  'तीन': np.int64(2027),
#  'भनेर': np.int64(2023),
#  'यसमा': np.int64(2022),
#  'दक्षिण': np.int64(2018),
#  'घर': np.int64(2003),
#  'अर्को': np.int64(1998),
#  'हाल': np.int64(1981),
#  'भएर': np.int64(1958),
#  'यसका': np.int64(1957),
#  'द्वारा': np.int64(1953),
#  'पृष्ठ': np.int64(1943),
#  'आएको': np.int64(1939),
#  'अञ्चलको': np.int64(1933),
#  'गते': np.int64(1931),
#  'त': np.int64(1930),
#  'श्री': np.int64(1930),
#  'साथ': np.int64(1928),
#  'राजनीतिक': np.int64(1917),
#  'आधारमा': np.int64(1916),
#  'पूजा': np.int64(1913),
#  'लाई': np.int64(1905),
#  'विशेष': np.int64(1886),
#  'पर्दछ': np.int64(1883),
#  'प्राचीन': np.int64(1880),
#  'गर्दछन्': np.int64(1868),
#  'ठाउँमा': np.int64(1850),
#  'जस्ता': np.int64(1835),
#  'गाविस': np.int64(1830),
#  'सदस्य': np.int64(1826),
#  'भारत': np.int64(1824),
#  'उत्तर': np.int64(1821),
#  'तपाईँ': np.int64(1812),
#  'सेवा': np.int64(1807),
#  'विश्व': np.int64(1803),
#  'पहिले': np.int64(1802),
#  'उनका': np.int64(1789),
#  'जनगणना': np.int64(1753),
#  'सफल': np.int64(1753),
#  'छन': np.int64(1751),
#  'भाषाको': np.int64(1740),
#  'उल्लेख': np.int64(1728),
#  'काठमाडौं': np.int64(1724),
#  'प्रकाशित': np.int64(1724),
#  'जसको': np.int64(1715),
#  'द': np.int64(1703),
#  'यसै': np.int64(1688),
#  'प्रकारको': np.int64(1684),
#  'अन्तर्गत': np.int64(1642),
#  'नदी': np.int64(1640),
#  'जसले': np.int64(1636),
#  'पटक': np.int64(1635),
#  'के': np.int64(1633),
#  'प्रदान': np.int64(1616),
#  'भारतमा': np.int64(1605),
#  'धार्मिक': np.int64(1602),
#  'दोस्रो': np.int64(1592),
#  'खेल': np.int64(1590),
#  'कुल': np.int64(1588),
#  'प्रकार': np.int64(1583),
#  'उच्च': np.int64(1570),
#  'क्षेत्रको': np.int64(1568),
#  'अन्तर्राष्ट्रिय': np.int64(1555),
#  'संयुक्त': np.int64(1552),
#  'इतिहास': np.int64(1539),
#  'भगवान': np.int64(1539),
#  'भित्र': np.int64(1532),
#  'हिन्दू': np.int64(1532),
#  'देखिन्छ': np.int64(1531),
#  'गर्छ': np.int64(1526),
#  'जसमा': np.int64(1524),
#  'ती': np.int64(1510),
#  'स्थानीय': np.int64(1502),
#  'साल': np.int64(1500),
#  'मध्ये': np.int64(1479),
#  'पाइने': np.int64(1473),
#  'शिक्षा': np.int64(1473),
#  'पश्चिम': np.int64(1468),
#  'चार': np.int64(1467),
#  'यस्तो': np.int64(1464),
#  'गर्यो': np.int64(1463),
#  'लेख': np.int64(1457),
#  'स्थान': np.int64(1454),
#  'त्यसैले': np.int64(1439),
#  'आर्थिक': np.int64(1433),
#  'धर्म': np.int64(1427),
#  'अध्ययन': np.int64(1420),
#  'त्यसको': np.int64(1416),
#  'अर्थ': np.int64(1406),
#  'त्यसपछि': np.int64(1406),
#  'प्रत्येक': np.int64(1400),
#  'विक्रम': np.int64(1392),
#  'अन्तिम': np.int64(1390),
#  'गाँउ': np.int64(1389),
#  'गरियो': np.int64(1387),
#  'व्यवस्था': np.int64(1386),
#  'सम्पादन': np.int64(1386),
#  'अफ': np.int64(1381),
#  'नेपालका': np.int64(1381),
#  'आफ्ना': np.int64(1377),
#  'लामो': np.int64(1377),
#  'सामाजिक': np.int64(1373),
#  'राष्ट्र': np.int64(1372),
#  'थिइन्': np.int64(1370),
#  'पुरुष': np.int64(1370),
#  'हुँदै': np.int64(1369),
#  'घोषणा': np.int64(1365),
#  'यसरी': np.int64(1363),
#  'बनेको': np.int64(1360),
#  'स्थानमा': np.int64(1353),
#  'गरि': np.int64(1346),
#  'पत्रिकाको': np.int64(1346),
#  'पुरस्कार': np.int64(1339),
#  'स्थित': np.int64(1331),
#  'कम': np.int64(1322),
#  'पर्छ': np.int64(1317),
#  'पानी': np.int64(1303),
#  'हजार': np.int64(1303),
#  'सक्छ': np.int64(1296),
#  'महत्वपूर्ण': np.int64(1295),
#  'विवाह': np.int64(1274),
#  'जसलाई': np.int64(1269),
#  'बसोबास': np.int64(1268),
#  'बारेमा': np.int64(1265),
#  'प्रथम': np.int64(1262),
#  'वर्षको': np.int64(1261),
#  'नामक': np.int64(1254),
#  'छोरा': np.int64(1250),
#  'गीत': np.int64(1247),
#  'ऐतिहासिक': np.int64(1239),
#  'राम्रो': np.int64(1239),
#  'केन्द्र': np.int64(1233),
#  'निकै': np.int64(1224),
#  'राजधानी': np.int64(1217),
#  'स्थापित': np.int64(1208),
#  'बेला': np.int64(1203),
#  'भई': np.int64(1203),
#  'दिने': np.int64(1195),
#  'म': np.int64(1191),
#  'खेलाडी': np.int64(1185),
#  'लगभग': np.int64(1185),
#  'प्रधानमन्त्री': np.int64(1182),
#  'अतिरिक्त': np.int64(1181),
#  'अहिले': np.int64(1177),
#  'क्रममा': np.int64(1175),
#  'क्रिकेट': np.int64(1170),
#  'प्रवेश': np.int64(1163),
#  'मृत्यु': np.int64(1158),
#  'तत्कालीन': np.int64(1153),
#  'जना': np.int64(1150),
#  'सय': np.int64(1141),
#  'कथा': np.int64(1140),
#  'भागमा': np.int64(1138),
#  'शब्द': np.int64(1138),
#  'सुरु': np.int64(1134),
#  'जब': np.int64(1128),
#  'हुँदा': np.int64(1127),
#  'अनि': np.int64(1126),
#  'लिखित': np.int64(1120),
#  'प्रकाशन': np.int64(1110),
#  'अगाडि': np.int64(1109),
#  'भाषामा': np.int64(1094),
#  'माथि': np.int64(1092),
#  'शासन': np.int64(1090),
#  'सानो': np.int64(1089),
#  'न': np.int64(1085),
#  'भएपछि': np.int64(1083),
#  'टिम': np.int64(1077),
#  'सो': np.int64(1077),
#  'शहर': np.int64(1067),
#  'गर्छन्': np.int64(1065),
#  'जीवन': np.int64(1062),
#  'मानव': np.int64(1058),
#  'लेखिएको': np.int64(1058),
#  'करिब': np.int64(1056),
#  'पूर्वी': np.int64(1056),
#  'थापा': np.int64(1051),
#  'उत्पादन': np.int64(1045),
#  'दिए': np.int64(1044),
#  'चलन': np.int64(1041),
#  'त्यस्तै': np.int64(1041),
#  'राज्यको': np.int64(1039),
#  'अधिकार': np.int64(1038),
#  'देश': np.int64(1037),
#  'नामले': np.int64(1037),
#  'प्रति': np.int64(1035),
#  'लिएर': np.int64(1035),
#  'अवस्थामा': np.int64(1031),
#  'भएकाले': np.int64(1030),
#  'गरिने': np.int64(1023),
#  'जस्तो': np.int64(1011),
#  'युद्ध': np.int64(1011),
#  'आएका': np.int64(1003),
#  'यही': np.int64(1000),
#  'पुरानो': np.int64(998),
#  'त्यहाँ': np.int64(997),
#  'थाले': np.int64(997),
#  'चाँडै': np.int64(996),
#  'विश्वास': np.int64(996),
#  'सम्पूर्ण': np.int64(994),
#  'आउने': np.int64(991),
#  'संविधान': np.int64(989),
#  'विचार': np.int64(985),
#  'गएको': np.int64(979),
#  'नं': np.int64(974),
#  'जहाँ': np.int64(973),
#  'शक': np.int64(969),
#  'सहमत': np.int64(966),
#  'क्याम्पस': np.int64(963),
#  'विश्वविद्यालय': np.int64(962),
#  'खेलमा': np.int64(955),
#  'ईपू': np.int64(951),
#  'उपन्यास': np.int64(945),
#  'जाने': np.int64(944),
#  'विद्यालय': np.int64(942),
#  'गोल': np.int64(939),
#  'सँग': np.int64(937),
#  'पार्टी': np.int64(935),
#  'हुनु': np.int64(935),
#  'सहयोग': np.int64(934),
#  'पहाडी': np.int64(931),
#  'अभिनेत्री': np.int64(929),
#  'हेर्नुहोला': np.int64(929),
#  'मान्यता': np.int64(927),
#  'यात्रा': np.int64(927),
#  'रोग': np.int64(927),
#  'शुरु': np.int64(925),
#  'लगायत': np.int64(923),
#  'यहाँको': np.int64(921),
#  'सञ्चालन': np.int64(921),
#  'अञ्चल': np.int64(920),
#  'कारणले': np.int64(920),
#  'मेटाउन': np.int64(918),
#  'परेको': np.int64(917),
#  'प्रतिशत': np.int64(913),
#  'भनेको': np.int64(911),
#  'सिंह': np.int64(911),
#  'हुनाले': np.int64(908),
#  'तपाईँले': np.int64(907),
#  'मेटाउनु': np.int64(905),
#  'सहर': np.int64(905),
#  'त्रिभुवन': np.int64(904),
#  'वार्तालापमा': np.int64(901),
#  'गरेकी': np.int64(899),
#  'अर्थात्': np.int64(895),
#  'लाख': np.int64(889),
#  'अघि': np.int64(888),
#  'गएर': np.int64(888),
#  'दुवै': np.int64(888),
#  'कम्पनी': np.int64(885),
#  'त्यही': np.int64(884),
#  'पत्रिका': np.int64(881),
#  'लाग्ने': np.int64(880),
#  'सम्पन्न': np.int64(879),
#  'निश्चित': np.int64(878),
#  'महिना': np.int64(878),
#  'राख्न': np.int64(877),
#  'सामान्य': np.int64(875),
#  'क्लब': np.int64(873),
#  'निर्वाचन': np.int64(871),
#  'लिएको': np.int64(870),
#  'अध्यक्ष': np.int64(867),
#  'अमेरिकी': np.int64(867),
#  'पाँच': np.int64(867),
#  'आयोजना': np.int64(863),
#  'औं': np.int64(863),
#  'बजार': np.int64(863),
#  'हेर्न': np.int64(862),
#  'गयो': np.int64(861),
#  'तल': np.int64(860),
#  'शाह': np.int64(860),
#  'सालको': np.int64(860),
#  'प्राकृतिक': np.int64(859),
#  'आधुनिक': np.int64(858),
#  'या': np.int64(858),
#  'सरकारी': np.int64(856),
#  'प्रचलित': np.int64(852),
#  'अधिकांश': np.int64(850),
#  'वर्ग': np.int64(848),
#  'नैं': np.int64(847),
#  'जम्मा': np.int64(846),
#  'प्रहरी': np.int64(846),
#  'बनाइएको': np.int64(846),
#  'हरेक': np.int64(846),
#  'तयार': np.int64(843),
#  'मिटर': np.int64(841),
#  'आधारित': np.int64(839),
#  'गाविसको': np.int64(839),
#  'सरकार': np.int64(838),
#  'सम्बन्धित': np.int64(837),
#  'घरमा': np.int64(835),
#  'तिर': np.int64(833),
#  'तेस्रो': np.int64(827),
#  'पश्चिममा': np.int64(827),
#  'गाविसमा': np.int64(824),
#  'बौद्ध': np.int64(824),
#  'सांस्कृतिक': np.int64(824),
#  'किलोमिटर': np.int64(820),
#  'ताल': np.int64(818),
#  'भएकोले': np.int64(818),
#  'आफ्नै': np.int64(816),
#  'बजारमा': np.int64(816),
#  'बनाउने': np.int64(812),
#  'भूमिका': np.int64(811),
#  'उपलब्ध': np.int64(809),
#  'आज': np.int64(808),
#  'व्यक्ति': np.int64(808),
#  'सरकारले': np.int64(808),
#  'शक्ति': np.int64(807),
#  'हुनुहुन्छ': np.int64(807),
#  'सार्वजनिक': np.int64(806),
#  'जनसंख्या': np.int64(805),
#  'भनी': np.int64(805),
#  'सम्बन्ध': np.int64(804),
#  'गई': np.int64(802),
#  'सदरमुकाम': np.int64(802),
#  'सम्पदा': np.int64(800),
#  'कर्णाली': np.int64(799),
#  'सुधार': np.int64(796),
#  'प्रस्तुत': np.int64(795),
#  'निम्न': np.int64(794),
#  'पूर्ण': np.int64(794),
#  'आवश्यक': np.int64(792),
#  'मन': np.int64(792),
#  'मानिसहरू': np.int64(792),
#  'आउँछ': np.int64(791),
#  'केन्द्रीय': np.int64(791),
#  'साझा': np.int64(790),
#  'अङ्ग्रेजी': np.int64(786),
#  'देशको': np.int64(786),
#  'उत्तरी': np.int64(782),
#  'त्यसै': np.int64(778),
#  'हिमाल': np.int64(778),
#  'परम्परा': np.int64(775),
#  'प्रतियोगिता': np.int64(773),
#  'समाचार': np.int64(773),
#  'अब': np.int64(772),
#  'कायम': np.int64(772),
#  'तर्फ': np.int64(772),
#  'बनाउन': np.int64(772),
#  'सहित': np.int64(767),
#  'कार्यक्रम': np.int64(766),
#  'पर्व': np.int64(766),
#  'पूरा': np.int64(766),
#  'उत्पन्न': np.int64(764),
#  'नदीको': np.int64(764),
#  'विभाजन': np.int64(764),
#  'सन': np.int64(764),
#  'उत्कृष्ट': np.int64(763),
#  'विज्ञान': np.int64(762),
#  'हाम्रो': np.int64(762),
#  'वडा': np.int64(761),
#  'कृष्ण': np.int64(759),
#  'लागी': np.int64(758),
#  'ठाउँ': np.int64(751),
#  'कृषि': np.int64(749),
#  'यस्ता': np.int64(748),
#  'ठुलो': np.int64(747),
#  'परिवर्तन': np.int64(747),
#  'पूर्वमा': np.int64(746),
#  'दक्षिणमा': np.int64(745),
#  'मेरो': np.int64(745),
#  'रेडियो': np.int64(744),
#  'राख्ने': np.int64(742),
#  'गाउँपालिका': np.int64(740),
#  'बीच': np.int64(740),
#  'वर्णन': np.int64(736),
#  'पर्न': np.int64(734),
#  'वर्तमान': np.int64(734),
#  'अस्पताल': np.int64(732),
#  'रूप': np.int64(731),
#  'राखिएको': np.int64(730),
#  'राणा': np.int64(727),
#  'प्रदेश': np.int64(726),
#  'व्यक्त': np.int64(725),
#  'निर्णय': np.int64(722),
#  'बाहिर': np.int64(721),
#  'रचना': np.int64(721),
#  'कुराको': np.int64(720),
#  'उत्तरमा': np.int64(719),
#  'मूल': np.int64(719),
#  'संस्कृत': np.int64(717),
#  'थाहा': np.int64(716),
#  'कविता': np.int64(714),
#  'आमा': np.int64(713),
#  'गौतम': np.int64(712),
#  'थिएन': np.int64(712),
#  'हामी': np.int64(709),
#  'स्वतन्त्र': np.int64(707),
#  'गए': np.int64(706),
#  'सक्ने': np.int64(706),
#  'कलेज': np.int64(705),
#  'लगायतका': np.int64(705),
#  'कुरामा': np.int64(699),
#  'जान्छ': np.int64(698),
#  'अभिनय': np.int64(697),
#  'दिएको': np.int64(697),
#  'भनिएको': np.int64(697),
#  'लिन': np.int64(696),
#  'गठन': np.int64(695),
#  'क्षेत्रफल': np.int64(693),
#  'परिवार': np.int64(693),
#  'प्रतिनिधित्व': np.int64(692),
#  'अमेरिकन': np.int64(691),
#  'ज्ञान': np.int64(691),
#  'फरक': np.int64(691),
#  'भारतका': np.int64(691),
#  'संख्या': np.int64(691),
#  'नगरपालिकाको': np.int64(690),
#  'पर्याप्त': np.int64(689),
#  'लिग': np.int64(688),
#  'कार्यालय': np.int64(685),
#  'चराको': np.int64(685),
#  'अनेक': np.int64(684),
#  'राष्ट्रपति': np.int64(684),
#  'खण्डमा': np.int64(683),
#  'लेखक': np.int64(681),
#  'संस्था': np.int64(681),
#  'यहाँका': np.int64(680),
#  'गरेपछि': np.int64(672),
#  'बाहेक': np.int64(671),
#  'बागमती': np.int64(670),
#  'प्रकारका': np.int64(668),
#  'प्रसाद': np.int64(668),
#  'हुँदैन': np.int64(668),
#  'बन्न': np.int64(667),
#  'ल्याएको': np.int64(664),
#  'संग': np.int64(661),
#  'स्वास्थ्य': np.int64(661),
#  'पवित्र': np.int64(660),
#  'बनेका': np.int64(660),
#  'लिने': np.int64(660),
#  'पूर्वका': np.int64(659),
#  'चर्चित': np.int64(658),
#  'थुप्रै': np.int64(658),
#  'मन्दिरमा': np.int64(658),
#  'सं': np.int64(658),
#  'उपन्यासकार': np.int64(655),
#  'जोडिएको': np.int64(655),
#  'योगदान': np.int64(655),
#  'अत्यन्त': np.int64(654),
#  'स्थल': np.int64(654),
#  'आधार': np.int64(653),
#  'प्रभाव': np.int64(653),
#  'अवस्था': np.int64(652),
#  'क्यालेण्डर': np.int64(649),
#  'दर्शन': np.int64(649),
#  'प्रकाशक': np.int64(648),
#  'होइन': np.int64(646),
#  'साहित्य': np.int64(644),
#  'गरिएका': np.int64(642),
#  'मिलेर': np.int64(641),
#  'राम': np.int64(640),
#  'ईसाको': np.int64(637),
#  'उमेरमा': np.int64(634),
#  'संस्कृति': np.int64(634),
#  'सक्नुहुन्छ': np.int64(634),
#  'अधिक': np.int64(631),
#  'दिएका': np.int64(631),
#  'बनाएर': np.int64(631),
#  'यिनको': np.int64(630),
#  'केवल': np.int64(629),
#  'पुगेको': np.int64(629),
#  'बीचमा': np.int64(628),
#  'मानिस': np.int64(628),
#  'पहिला': np.int64(627),
#  'अरु': np.int64(625),
#  'उहाँ': np.int64(625),
#  'बस्ने': np.int64(625),
#  'समूह': np.int64(625),
#  'माध्यमिक': np.int64(623),
#  'आएर': np.int64(622),
#  'छोरी': np.int64(620),
#  'प्रधान': np.int64(620),
#  'कृति': np.int64(619),
#  'बने': np.int64(618),
#  'सम्मान': np.int64(618),
#  'बाटो': np.int64(617),
#  'विश्वमा': np.int64(617),
#  'जाति': np.int64(616),
#  'जन्मदेखि': np.int64(615),
#  'अर्थात': np.int64(612),
#  'सात': np.int64(612),
#  'पछी': np.int64(611),
#  'सप्तर्षि': np.int64(611),
#  'काठमाडौंमा': np.int64(610),
#  'खोला': np.int64(610),
#  'देशमा': np.int64(609),
#  'निर्वाचित': np.int64(609),
#  'अलग': np.int64(608),
#  'कोशी': np.int64(607),
#  'सगरमाथा': np.int64(607),
#  'उपाधि': np.int64(606),
#  'ललितपुर': np.int64(606),
#  'लुम्बिनी': np.int64(603),
#  'पुस्तक': np.int64(602),
#  'आक्रमण': np.int64(601),
#  'फल': np.int64(601),
#  'लागेको': np.int64(601),
#  'संरक्षण': np.int64(601),
#  'त्यसलाई': np.int64(598),
#  'सुन्दर': np.int64(598),
#  'जारी': np.int64(597),
#  'पुराना': np.int64(597),
#  'पर्वत': np.int64(595),
#  'पुत्र': np.int64(592),
#  'सरकारको': np.int64(592),
#  'बनाएको': np.int64(590),
#  'नामबाट': np.int64(589),
#  'शान्ति': np.int64(589),
#  'अङ्ग्रेजीमा': np.int64(588),
#  'दल': np.int64(587),
#  'बनाउनु': np.int64(587),
#  'क्षेत्रका': np.int64(586),
#  'नगर': np.int64(586),
#  'सभा': np.int64(582),
#  'एकपटक': np.int64(581),
#  'डा': np.int64(581),
#  'रहन': np.int64(581),
#  'रातो': np.int64(581),
#  'आरम्भ': np.int64(578),
#  'जानकारी': np.int64(578),
#  'बहादुर': np.int64(578),
#  'प्रतिक्रिया': np.int64(577),
#  'डोटी': np.int64(573),
#  'फैलिएको': np.int64(572),
#  'सृजना': np.int64(572),
#  'चिनिन्छ': np.int64(571),
#  'छिन्': np.int64(570),
#  'देवता': np.int64(569),
#  'सुरू': np.int64(569),
#  'देवी': np.int64(568),
#  'लोकप्रिय': np.int64(568),
#  'आधिकारिक': np.int64(566),
#  'राजाको': np.int64(566),
#  'दिइएको': np.int64(565),
#  'श्रेष्ठ': np.int64(565),
#  'पिता': np.int64(564),
#  'रहने': np.int64(564),
#  'मत': np.int64(563),
#  'वैज्ञानिक': np.int64(563),
#  'युवा': np.int64(562),
#  'विजय': np.int64(561),
#  'साना': np.int64(561),
#  'नेता': np.int64(560),
#  'देखेर': np.int64(559),
#  'रहन्छ': np.int64(559),
#  'खेल्ने': np.int64(558),
#  'मैले': np.int64(558),
#  'समस्या': np.int64(558),
#  'पाल्पा': np.int64(557),
#  'मल्ल': np.int64(556),
#  'प्राय': np.int64(555),
#  'नेकपा': np.int64(554),
#  'वेब': np.int64(554),
#  'थप': np.int64(553),
#  'अति': np.int64(552),
#  'विषयमा': np.int64(552),
#  'करोड': np.int64(550),
#  'प्रतियोगितामा': np.int64(550),
#  'मात्रै': np.int64(550),
#  'निम्ति': np.int64(549),
#  'यिनी': np.int64(548),
#  'हिन्दी': np.int64(548),
#  'दिनमा': np.int64(545),
#  'नुवाकोट': np.int64(545),
#  'युद्धमा': np.int64(544),
#  'हात': np.int64(544),
#  'चलचित्रमा': np.int64(543),
#  'जनवरी': np.int64(542),
#  'मन्दिरको': np.int64(541),
#  'संघको': np.int64(541),
#  'सक्रिय': np.int64(541),
#  'दरबार': np.int64(538),
#  'उनीहरू': np.int64(537),
#  'ठूला': np.int64(536),
#  'उपत्यका': np.int64(535),
#  'प्रत्यक्ष': np.int64(535),
#  'फेरि': np.int64(535),
#  'वि': np.int64(534),
#  'राजाले': np.int64(533),
#  'फिफा': np.int64(532),
#  'शिव': np.int64(532),
#  'इतिहासमा': np.int64(531),
#  'अमेरिका': np.int64(530),
#  'पश्चिमाञ्चल': np.int64(530),
#  'ढाँचा': np.int64(529),
#  'थर': np.int64(528),
#  'महत्व': np.int64(528),
#  'आफूलाई': np.int64(527),
#  'एउटै': np.int64(527),
#  'जति': np.int64(527),
#  'रूपले': np.int64(526),
#  'हुनेछ': np.int64(526),
#  'गराउने': np.int64(525),
#  'सन्तान': np.int64(524),
#  'हिन्दु': np.int64(524),
#  'अग्लो': np.int64(523),
#  'उनि': np.int64(523),
#  'तब': np.int64(523),
#  'अनुमान': np.int64(522),
#  'प्रबन्धक': np.int64(522),
#  'लागू': np.int64(521),
#  'गर्छन': np.int64(520),
#  'जुम्ला': np.int64(520),
#  'उपचार': np.int64(519),
#  'मगर': np.int64(519),
#  'पर्दछन्': np.int64(518),
#  'पुनः': np.int64(518),
#  'सम्बन्धन': np.int64(518),
#  'आफैले': np.int64(517),
#  'पश्चिमी': np.int64(517),
#  'रहे': np.int64(517),
#  'गर्नको': np.int64(516),
#  'पुन': np.int64(515),
#  'खान': np.int64(514),
#  'मापदण्ड': np.int64(514),
#  'खाने': np.int64(513),
#  'ध्यान': np.int64(513),
#  'कालमा': np.int64(512),
#  'केहि': np.int64(512),
#  'अवधिमा': np.int64(511),
#  'विश्वको': np.int64(511),
#  'कवि': np.int64(510),
#  'डिग्री': np.int64(510),
#  'उपयोग': np.int64(509),
#  'भक्तपुर': np.int64(509),
#  'मात्रामा': np.int64(509),
#  'समाजमा': np.int64(508),
#  'देख्न': np.int64(507),
#  'समावेश': np.int64(507),
#  'स्पष्ट': np.int64(507),
#  'किन': np.int64(505),
#  'राजनीतिमा': np.int64(505),
#  'सिधै': np.int64(505),
#  'आचार्य': np.int64(504),
#  'जनताको': np.int64(504),
#  'धर्मको': np.int64(504),
#  'सङ्गठन': np.int64(504),
#  'सैनिक': np.int64(504),
#  'उसको': np.int64(503),
#  'कृपया': np.int64(503),
#  'सडक': np.int64(503),
#  'पार्टीको': np.int64(502),
#  'माओवादी': np.int64(502),
#  'लगाउने': np.int64(502),
#  'क्षमता': np.int64(501),
#  'जातिको': np.int64(500),
#  'भन्नाले': np.int64(500),
#  'संस्कार': np.int64(500),
#  'सेतो': np.int64(500),
#  'सेना': np.int64(498),
#  'निर्वाचनमा': np.int64(497),
#  'प्रचलन': np.int64(497),
#  'फूल': np.int64(497),
#  'भन्न': np.int64(497),
#  'मनाउने': np.int64(497),
#  'खस': np.int64(495),
#  'प्रकाशनले': np.int64(495),
#  'जीवनको': np.int64(494),
#  'ब्रिटिश': np.int64(494),
#  'वैदिक': np.int64(494),
#  'आन्दोलन': np.int64(493),
#  'प्रयास': np.int64(493),
#  'विरुद्ध': np.int64(493),
#  'गण्डकी': np.int64(490),
#  'नियम': np.int64(490),
#  'पाउने': np.int64(490),
#  'मन्त्री': np.int64(490),
#  'सबभन्दा': np.int64(490),
#  'सहभागी': np.int64(490),
#  'जिल्लाका': np.int64(489),
#  'पुगे': np.int64(489),
#  'वनस्पति': np.int64(487),
#  'समाज': np.int64(487),
#  'पर्यटकीय': np.int64(486),
#  'बैंक': np.int64(486),
#  'मेला': np.int64(486),
#  'सम्बन्धी': np.int64(486),
#  'कला': np.int64(485),
#  'राज्यमा': np.int64(484),
#  'साधारण': np.int64(484),
#  'प्रणाली': np.int64(483),
#  'भौगोलिक': np.int64(483),
#  'झापा': np.int64(482),
#  'तत्कालिन': np.int64(482),
#  'मार्च': np.int64(482),
#  'विषय': np.int64(482),
#  'तर्फबाट': np.int64(481),
#  'पुग्यो': np.int64(481),
#  'विकसित': np.int64(481),
#  'सर्वाधिक': np.int64(481),
#  'भौतिक': np.int64(480),
#  'गर्नका': np.int64(479),
#  'ब्राह्मण': np.int64(479),
#  'माघ': np.int64(479),
#  'हेर्दा': np.int64(479),
#  'आए': np.int64(478),
#  'गणना': np.int64(478),
#  'हासिल': np.int64(478),
#  'गुगल': np.int64(476),
#  'तिनको': np.int64(476),
#  'परम्परागत': np.int64(476),
#  'किमी': np.int64(475),
#  'योजना': np.int64(475),
#  'आधारको': np.int64(474),
#  'जान': np.int64(474),
#  'मे': np.int64(474),
#  'उहाँले': np.int64(473),
#  'हुदै': np.int64(472),
#  'आदिमा': np.int64(471),
#  'उहाँको': np.int64(471),
#  'दक्षिणी': np.int64(471),
#  'पश्चात': np.int64(470),
#  'हे': np.int64(470),
#  'कर': np.int64(469),
#  'नाममा': np.int64(469),
#  'पृष्ठको': np.int64(469),
#  'गुरु': np.int64(468),
#  'सकिनेछ': np.int64(468),
#  'उद्देश्य': np.int64(467),
#  'विशाल': np.int64(467),
#  'सम्मको': np.int64(467),
#  'कसरी': np.int64(466),
#  'समाप्त': np.int64(466),
#  'कालो': np.int64(465),
#  'बटन': np.int64(465),
#  'व्रत': np.int64(465),
#  'बसेको': np.int64(463),
#  'संघ': np.int64(463),
#  'नपरेको': np.int64(462),
#  'मेटाउने': np.int64(462),
#  'लिङ्कहरू': np.int64(462),
#  'मध्येको': np.int64(461),
#  'मानेर': np.int64(461),
#  'यस्तै': np.int64(461),
#  'उनीहरूको': np.int64(460),
#  'गरिन्': np.int64(460),
#  'मलाई': np.int64(460),
#  'मोरङ': np.int64(460),
#  'सम्बत': np.int64(460),
#  'ग्रहण': np.int64(459),
#  'सक्नुहुनेछ': np.int64(459),
#  'अभिनेता': np.int64(458),
#  'नामको': np.int64(458),
#  'डिसेम्बर': np.int64(457),
#  'निर्देशक': np.int64(455),
#  'गर्नुहोला': np.int64(454),
#  'पुरा': np.int64(454),
#  'बन्यो': np.int64(454),
#  'हुनुहुन्न': np.int64(454),
#  'उसले': np.int64(453),
#  'गाउँमा': np.int64(453),
#  'प्रदेशको': np.int64(453),
#  'महेन्द्र': np.int64(453),
#  'समान': np.int64(453),
#  'अझ': np.int64(452),
#  'अझै': np.int64(452),
#  'पाइन्छन्': np.int64(452),
#  'मापदण्डमा': np.int64(452),
#  'शुक्ल': np.int64(452),
#  'अनुपयुक्त': np.int64(451),
#  'धनकुटा': np.int64(451),
#  'मार्फत': np.int64(451),
#  'राखिसकेपछि': np.int64(451),
#  'शर्मा': np.int64(451),
#  'नहटाउनुहोला': np.int64(450),
#  'प्रशासकद्वारा': np.int64(450),
#  'बर्ष': np.int64(450),
#  'थिच्नुहोला': np.int64(449),
#  'युटिसीमा': np.int64(449),
#  'लगहरू': np.int64(449),
#  'विस्तार': np.int64(449),
#  'हटाउनुहोला': np.int64(449),
#  'पष्ठलाई': np.int64(448),
#  'प्रबन्धकहरूको': np.int64(448),
#  'मेटाउनुभन्दा': np.int64(448),
#  'सोही': np.int64(447),
#  'ऋषि': np.int64(446),
#  'चीन': np.int64(446),
#  'नेपालले': np.int64(446),
#  'कानुन': np.int64(444),
#  'नियुक्त': np.int64(443),
#  'राखेर': np.int64(443),
#  'ः': np.int64(442),
#  'शब्दको': np.int64(442),
#  'हिमाली': np.int64(442),
#  'नेतृत्व': np.int64(441),
#  'लामा': np.int64(441),
#  'देखा': np.int64(440),
#  'नम्बर': np.int64(440),
#  'मध्यमाञ्चल': np.int64(440),
#  'यिनले': np.int64(440),
#  'संलग्न': np.int64(440),
#  'सकेको': np.int64(440),
#  'सामान्यतया': np.int64(438),
#  'उद्योग': np.int64(437),
#  'काठमाडौंको': np.int64(436),
#  'आठ': np.int64(435),
#  'जनता': np.int64(435),
#  'थाल्यो': np.int64(435),
#  'पराजित': np.int64(435),
#  'सिन्धुपाल्चोक': np.int64(435),
#  'सुरुवात': np.int64(435),
#  'पहिचान': np.int64(434),
#  'पोखरी': np.int64(434),
#  'हत्या': np.int64(434),
#  'दैलेख': np.int64(433),
#  'परिवारमा': np.int64(433),
#  'विस': np.int64(433),
#  'शुरू': np.int64(433),
#  'शैक्षिक': np.int64(433),
#  'मानिसको': np.int64(432),
#  'एकै': np.int64(431),
#  'नियन्त्रण': np.int64(431),
#  'की': np.int64(430),
#  'दुइ': np.int64(430),
#  'नवलपरासी': np.int64(430),
#  'कपिलवस्तु': np.int64(429),
#  'गर्दथे': np.int64(429),
#  'सुनसरी': np.int64(429),
#  'ईसा': np.int64(428),
#  'खेती': np.int64(428),
#  'चौथो': np.int64(428),
#  'बुद्ध': np.int64(428),
#  'वन': np.int64(428),
#  'गुल्मी': np.int64(427),
#  'ग्रन्थ': np.int64(426),
#  'मुक्त': np.int64(426),
#  'सुबेदी': np.int64(426),
#  'इलाम': np.int64(425),
#  'उपयुक्त': np.int64(424),
#  'पदार्थ': np.int64(424),
#  'मानिएको': np.int64(424),
#  'उपर्युक्त': np.int64(423),
#  'किसिमको': np.int64(423),
#  'दैनिक': np.int64(423),
#  'नीति': np.int64(423),
#  'नागरिक': np.int64(422),
#  'पौराणिक': np.int64(422),
#  'बनाए': np.int64(422),
#  'भवन': np.int64(422),
#  'सहायक': np.int64(422),
#  'अरू': np.int64(420),
#  'टाढा': np.int64(420),
#  'अमेरिकाको': np.int64(419),
#  'जात्रा': np.int64(419),
#  'भूभाग': np.int64(419),
#  'शाही': np.int64(419),
#  'सामूहिक': np.int64(419),
#  'अक्टोबर': np.int64(418),
#  'त्यसमा': np.int64(418),
#  'दिएर': np.int64(418),
#  'कूल': np.int64(417),
#  ...}
